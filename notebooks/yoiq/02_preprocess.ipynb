# %%
import mlflow
from lib.constants import EXPERIMENT_NAME, MLFLOW_URI
from lib.dataset import load_train_data, load_test_data

# Make sure to have the MLFlow server on before running this code.
# mlflow.set_tracking_uri(uri=MLFLOW_URI)
# experiment = mlflow.set_experiment(EXPERIMENT_NAME)
X_train, y_train = load_train_data()
X_test = load_test_data()

# %%
import numpy as np
import pandas as pd

from lib.sklearn.preprocess import nlp

X = X_train + X_test

tokenizer = nlp.TextTokenizer()
X_tokenized = tokenizer.transform(X)

formalizer = nlp.WordsFormalizer()
X_formalized = formalizer.transform(X_tokenized)

custom_map = {
    row['asal']: row['tujuan']
    for _, row in pd.read_csv('custom-mapper.csv').iterrows()
}
custom_mapper = nlp.WordsMapper(custom_map)
X_custom_mapped = custom_mapper.transform(X_formalized)

lemmatization = nlp.WordsLemmatization()
X_lemmatization = lemmatization.transform(X_custom_mapped)

special_char_filter = nlp.SpecialCharacterFilter()
X_special_char_filtered = special_char_filter.transform(X_lemmatization)

# stop_words_filter = nlp.StopWordsFilter()
# X_stop_words_filtered = stop_words_filter.transform(X_special_char_filtered)
X_stop_words_filtered = X_special_char_filtered

unknown_words_filter = nlp.UnknownWordsFilter()
X_unknown_words_filtered = unknown_words_filter.transform(X_stop_words_filtered)

X_transformed = X_unknown_words_filtered
X_transformed
# Out:
# [['layan', 'adalah', 'tidak', 'sahabat', 'person', 'malam', 'jaga', 'gelas'],
#  ['kakak',
#   'enak',
#   'sangat',
#   'layan',
#   'cepat',
#   'tanggap',
#   'dan',
#   'yang',
#   'pertama',
#   'murah',
#   'senyum'],
#  ['layan', 'sangat', 'ramah', 'banyak', 'promosi'],
#  ['tempat', 'nyaman', 'dan', 'bersih'],
#  ['layan',
#   'cepat',
#   'dan',
#   'bagus',
#   'coba',
#   'durian',
#   'yang',
#   'baru',
#   'mantap'],
#  ['enak', 'nyaman'],
#  ['cepat', 'ramah', 'baik'],
#  ['layan',
#   'lama',
#   'semrawut',
#   'sani',
#   'pesan',
#   'langgan',
#   'yang',
#   'order',
#   'kalah',
#   'cepat',
#   'dengan',
#   'yang',
#   'order',
#   'belakang',
#   'ayo',
#   'semangat',
#   'benah',
#   'untuk',
#   'lebih',
#   'baik',
#   'lagi'],
#  ['tempat',
#   'paling',
#   'baik',
#   'buat',
#   'tugas',
#   'layan',
#   'ramah',
#   'cuma',
#   'wastafel',
#   'lantai',
#   'tidak',
#   'bisa',
#   'nyala',
#   'cara',
#   'seluruh',
#   'semua',
#   'bagus'],
#  ['layan', 'ramah', 'mutu', 'selalu', 'stabil', 'rasa', 'kopi'],
#  ['banyak', 'banget'],
#  ['makas', 'mantap'],
#  ['layan',
#   'super',
#   'lama',
#   'dan',
#   'pegawai',
#   'wanita',
#   'tidak',
#   'sopan',
#   'dan',
#   'cara',
#   'bicara',
#   'kasar',
#   'beli'],
#  ['soto', 'jalan', 'anti'],
#  ['enak',
#   'buat',
#   'tongkrong',
#   'atau',
#   'kerja',
#   'tugas',
#   'karena',
#   'tempat',
#   'luas',
#   'bersih',
#   'tidak',
#   'terlalu',
#   'ramai',
#   'tiap',
#   'meja',
#   'ada',
#   'colok',
#   'dan',
#   'jika',
#   'kita',
#   'kabel',
#   'mereka',
#   'sedia',
#   'untuk',
#   'pinjam',
#   'gratis',
#   'kopi',
#   'dan',
#   'makan',
#   'tidak',
#   'perlu',
#   'ragu',
#   'lagi',
#   'sesuai',
#   'standar'],
#  ['layan', 'oke', 'deh', 'tempat', 'juga', 'bersih'],
#  ['ada', 'area', 'balkon', 'enak', 'buat', 'rileks'],
#  ['buat', 'yang', 'mau', 'santai', 'atau', 'rapat', 'kecil'],
#  ['tempat', 'kumpul', 'keluarga', 'yang', 'sangat', 'rekomendasi'],
#  ['salah',
#   'satu',
#   'tempat',
#   'minum',
#   'kopi',
#   'teh',
#   'dan',
#   'santa',
#   'jenak',
#   'ketika',
#   'belanja',
#   'tunjung',
#   'plaza'],
#  ['nyaman',
#   'sekali',
#   'waktu',
#   'datang',
#   'juga',
#   'tidak',
#   'ramai',
#   'jual',
#   'kasih',
#   'saran',
#   'minum',
#   'yang',
#   'oke',
#   'juga',
#   'untuk',
#   'harga',
#   'cenderung',
#   'murah',
#   'juga'],
#  ['beli',
#   'lewat',
#   'aplikasi',
#   'karena',
#   'lagi',
#   'ada',
#   'promosi',
#   'kue',
#   'krim',
#   'enak',
#   'manis',
#   'pas',
#   'tidak',
#   'manis',
#   'rata',
#   'minum',
#   'kue',
#   'krim',
#   'manis',
#   'over',
#   'tetapi',
#   'ini',
#   'enggak',
#   'tidak',
#   'pelit'],
#  ['mesan',
#   'cepat',
#   'guna',
#   'aplikasi',
#   'kopi',
#   'saji',
#   'cukup',
#   'cepat',
#   'tidak',
#   'sampai',
#   'menit',
#   'sedia',
#   'meja',
#   'dan',
#   'kursi',
#   'untuk',
#   'tunggu',
#   'namun',
#   'tidak',
#   'banyak'],
#  [],
#  ['ayam',
#   'bakar',
#   'januari',
#   'harga',
#   'murah',
#   'rasa',
#   'enak',
#   'parkir',
#   'luas',
#   'bisa',
#   'tampung',
#   'mobil',
#   'bisa',
#   'tampung',
#   'orang',
#   'variasi',
#   'makan',
#   'cukup',
#   'banyak',
#   'dan',
#   'masakan',
#   'umum',
#   'tapi',
#   'enak',
#   'saji',
#   'juga',
#   'cepat',
#   'dukung',
#   'ekonomi',
#   'lokal'],
#  ['tempat',
#   'yang',
#   'cocok',
#   'buat',
#   'relaksasi',
#   'pikir',
#   'sambil',
#   'minum',
#   'kopi'],
#  ['aplikasi',
#   'aplikasi',
#   'makan',
#   'jangan',
#   'aktif',
#   'kalau',
#   'belum',
#   'siap',
#   'bos',
#   'utama',
#   'pagi',
#   'karena',
#   'jual',
#   'minum',
#   'tidak',
#   'bisa',
#   'hubung',
#   'klub',
#   'begini',
#   'kasihan',
#   'para',
#   'bos',
#   'kena',
#   'dompet',
#   'langgan'],
#  ['salah', 'satu', 'minum', 'yang', 'aku', 'suka', 'wajib', 'banget', 'coba'],
#  ['layan', 'lama', 'karena', 'jual', 'satu', 'aja'],
#  ['rasa',
#   'dan',
#   'kualitas',
#   'sesuai',
#   'moga',
#   'tetap',
#   'konsisten',
#   'kena',
#   'rasa',
#   'toko',
#   'ini'],
#  ['tempat',
#   'agak',
#   'kecil',
#   'jadi',
#   'kalau',
#   'dalem',
#   'penuh',
#   'harus',
#   'yang',
#   'luar',
#   'ruang',
#   'apalagi',
#   'kalau',
#   'ada',
#   'giat',
#   'tidak',
#   'bakal',
#   'bagi',
#   'dalam'],
#  ['enak', 'sekali', 'dan', 'nyaman', 'suasana'],
#  ['tempat', 'nyaman', 'bersih', 'fasilitas', 'oke', 'sangat', 'deh'],
#  ['layan', 'ramah'],
#  ['lokasi',
#   'ada',
#   'dalam',
#   'bensin',
#   'parkir',
#   'banyak',
#   'mudah',
#   'dan',
#   'gratis',
#   'lokasi',
#   'strategis',
#   'akses',
#   'mudah',
#   'layan',
#   'ramah',
#   'kopi',
#   'enak',
#   'tata',
#   'rapi',
#   'dalam',
#   'ruang',
#   'sejuk',
#   'karena',
#   'ada',
#   'dingin',
#   'ruang',
#   'dan',
#   'bersih',
#   'juga',
#   'lokasi',
#   'parkir',
#   'ada',
#   'depan',
#   'kedai',
#   'kopi',
#   'tidak',
#   'cocok',
#   'untuk',
#   'anak'],
#  ['tempat', 'sempit'],
#  ['cantik', 'cantik'],
#  ['cuma', 'antri', 'tempat', 'parkir'],
#  ['enak', 'mantap', 'banget'],
#  ['cari', 'angin', 'tipis'],
#  ['layan',
#   'lambat',
#   'kurang',
#   'ramah',
#   'pesan',
#   'satu',
#   'menu',
#   'saja',
#   'hampir',
#   'jam'],
#  ['sangat', 'saran', 'semua', 'layan', 'semua', 'kru', 'juga', 'ramah'],
#  ['paling', 'enak', 'baik', 'baik'],
#  ['tempat',
#   'yang',
#   'nyaman',
#   'makan',
#   'minum',
#   'oke',
#   'goreng',
#   'kurang',
#   'lain',
#   'kali',
#   'saya',
#   'tidak',
#   'akan',
#   'pesan'],
#  ['mantap', 'enak'],
#  ['kasir',
#   'ramah',
#   'banget',
#   'banget',
#   'banget',
#   'nama',
#   'kasir',
#   'kak',
#   'tebak',
#   'jadi',
#   'yang',
#   'tulis',
#   'layar',
#   'seperti',
#   'itu',
#   'aku',
#   'beli',
#   'pakai',
#   'kupon',
#   'dari',
#   'salah',
#   'satu',
#   'aplikasi',
#   'biasa',
#   'kasir',
#   'langsung',
#   'galak',
#   'kalau',
#   'langgan',
#   'beli',
#   'pakai',
#   'promosi',
#   'ini',
#   'tidak',
#   'dong',
#   'ramah',
#   'banget',
#   'posisi',
#   'sudah',
#   'pesan',
#   'minum',
#   'dan',
#   'aku',
#   'lupa',
#   'cara',
#   'pakai',
#   'kupon',
#   'kakak',
#   'suruh',
#   'buat',
#   'ingat',
#   'cara',
#   'pakai',
#   'kupon',
#   'padahal',
#   'itu',
#   'aku',
#   'sudah',
#   'bilang',
#   'buat',
#   'tidak',
#   'usah',
#   'pakai',
#   'kupon',
#   'aja',
#   'banget',
#   'pokok',
#   'terima',
#   'kasih',
#   'banyak',
#   'kak'],
#  ['gurih', 'kering', 'enak', 'sangat', 'hanya', 'buka', 'sampai', 'aja'],
#  ['tempat', 'nyaman', 'dan', 'bagus', 'sekali'],
#  ['beli',
#   'super',
#   'buah',
#   'gula',
#   'normal',
#   'gula',
#   'ini',
#   'seperti',
#   'man',
#   'buat',
#   'ketika',
#   'minum',
#   'es',
#   'teh',
#   'selalu',
#   'telah',
#   'rasa',
#   'mulut',
#   'dan',
#   'lidah',
#   'itu',
#   'mirip',
#   'sekali',
#   'dengan',
#   'minum',
#   'man',
#   'buat',
#   'ketika',
#   'beli',
#   'toko',
#   'lain',
#   'seperti',
#   'itu',
#   'tidak',
#   'ada',
#   'telah',
#   'rasa',
#   'seperti',
#   'ini'],
#  ['untuk',
#   'pria',
#   'fajar',
#   'kalo',
#   'ada',
#   'masalah',
#   'baik',
#   'pulang',
#   'aja',
#   'deh',
#   'daripada',
#   'galak',
#   'banget',
#   'sama',
#   'langgan'],
#  ['tempat',
#   'yang',
#   'oke',
#   'banget',
#   'buat',
#   'tongkrong',
#   'ketemu',
#   'teman',
#   'atau',
#   'kerja',
#   'dengan',
#   'laptop',
#   'kopi',
#   'dan',
#   'makan',
#   'standar',
#   'selalu',
#   'jadi',
#   'tempat',
#   'suka',
#   'semua',
#   'cabang'],
#  ['layan', 'ramah', 'hanya', 'agak', 'lama', 'kalau', 'ramai'],
#  ['murah', 'enak', 'layan', 'bagus', 'ramah', 'saran'],
#  ['tempat',
#   'bersih',
#   'nyaman',
#   'menu',
#   'rekomendasi',
#   'harga',
#   'juga',
#   'jangkau'],
#  ['sih', 'tempat', 'enak', 'banget', 'buat', 'rapat', 'satu', 'tongkrong'],
#  ['cocok',
#   'untuk',
#   'kerja',
#   'tugas',
#   'kurang',
#   'cocok',
#   'untuk',
#   'yang',
#   'dompet',
#   'kayak',
#   'saya'],
#  ['beli',
#   'pakai',
#   'aplikasi',
#   'paket',
#   'rawon',
#   'dan',
#   'rawon',
#   'kuah',
#   'tetapi',
#   'yang',
#   'datang',
#   'kuah',
#   'rawon',
#   'saja',
#   'iris',
#   'daging',
#   'kecil',
#   'cuma',
#   'sudah',
#   'bayar',
#   'lagi',
#   'telah',
#   'dapat',
#   'promosi',
#   'benar',
#   'saja'],
#  ['tempat',
#   'nyaman',
#   'banget',
#   'walau',
#   'tidak',
#   'terlalu',
#   'besar',
#   'ada',
#   'dingin',
#   'dan',
#   'toilet',
#   'dalam',
#   'coba',
#   'krim',
#   'keju',
#   'enak',
#   'dan',
#   'tidak',
#   'manis',
#   'banget',
#   'walaupun',
#   'sudah',
#   'dingin',
#   'tetapi',
#   'rasa',
#   'krim',
#   'keju',
#   'tidak',
#   'terlalu',
#   'asa',
#   'layan',
#   'juga',
#   'mantap'],
#  ['tempat',
#   'sih',
#   'nyaman',
#   'layan',
#   'juga',
#   'oke',
#   'banget',
#   'sayang',
#   'mau',
#   'masuk',
#   'dalam',
#   'sulit',
#   'jalan',
#   'kecil',
#   'banget',
#   'belum',
#   'lagi',
#   'kalo',
#   'bareng',
#   'sama',
#   'yang',
#   'lagi',
#   'bayar',
#   'atau',
#   'pegawai',
#   'yang',
#   'diri',
#   'depan',
#   'kasir'],
#  ['teman',
#   'yang',
#   'cocok',
#   'banget',
#   'kalian',
#   'wajib',
#   'coba',
#   'sih',
#   'ini',
#   'enak',
#   'banget'],
#  ['tempat',
#   'ini',
#   'menu',
#   'utama',
#   'awal',
#   'ayam',
#   'tetapi',
#   'sudah',
#   'ada',
#   'kembang',
#   'menu',
#   'nasi',
#   'dan',
#   'penyet',
#   'dari',
#   'harga',
#   'sesuai',
#   'dengan',
#   'apa',
#   'yang',
#   'dapat',
#   'rekomendasi'],
#  ['tunggu',
#   'lama',
#   'sangat',
#   'layan',
#   'sudah',
#   'tunggu',
#   'lebih',
#   'dari',
#   'menit',
#   'malah',
#   'sudah',
#   'dingin'],
#  ['saya', 'top', 'global', 'pesan', 'gaco', 'via'],
#  ['enak',
#   'lembut',
#   'kenyal',
#   'ayam',
#   'dan',
#   'kaldu',
#   'asa',
#   'banget',
#   'pangsit',
#   'dan',
#   'bakso',
#   'juga',
#   'enak',
#   'kuah',
#   'ringan',
#   'kalau',
#   'turut',
#   'saya',
#   'kuah',
#   'rasa',
#   'cina',
#   'suka',
#   'banget',
#   'kuah',
#   'yang',
#   'model',
#   'begini',
#   'ringan',
#   'segar',
#   'tapi',
#   'enak',
#   'enak'],
#  ['parkir', 'luas', 'ada', 'oleh', 'oleh', 'restoran', 'juga'],
#  ['ukur', 'bikin', 'kenyang', 'dan', 'lagi', 'gerai', 'temu'],
#  ['selalu',
#   'jadi',
#   'tempat',
#   'yang',
#   'nyaman',
#   'dan',
#   'pas',
#   'untuk',
#   'minum',
#   'kopi',
#   'santai',
#   'dan',
#   'bicara',
#   'dengan',
#   'rekan',
#   'bisnis'],
#  ['banyak', 'promosi', 'minum', 'suka', 'sekali'],
#  ['enak', 'minum', 'yang', 'ada', 'sama', 'roti', 'keju', 'manis'],
#  ['enak',
#   'suasana',
#   'juga',
#   'nyaman',
#   'pegawai',
#   'ramah',
#   'cuma',
#   'yang',
#   'putar',
#   'kadang',
#   'terlalu',
#   'besar',
#   'volume'],
#  ['paling'],
#  ['mas', 'ramah', 'sangat'],
#  ['karena',
#   'uda',
#   'biasa',
#   'ama',
#   'beli',
#   'antri',
#   'plus',
#   'buru',
#   'semua',
#   'jadi',
#   'tugas',
#   'sigap',
#   'banget',
#   'cepat',
#   'tetapi',
#   'sabar',
#   'layan',
#   'tanya',
#   'sampai',
#   'kartu',
#   'macet',
#   'tetap',
#   'telaten',
#   'kopi',
#   'enak',
#   'seperti',
#   'biasa',
#   'cepat',
#   'pula',
#   'keren'],
#  ['makan', 'enak', 'suasana', 'enak'],
#  ['saji', 'cepat', 'layan', 'cukup', 'ramah', 'tempat', 'bersih'],
#  ['mantap',
#   'jiwa',
#   'baru',
#   'pertama',
#   'kali',
#   'minum',
#   'kopi',
#   'sini',
#   'tapi',
#   'langsung',
#   'enak',
#   'dan',
#   'sen',
#   'tidak',
#   'rumit',
#   'sayang',
#   'kursi',
#   'sedikit',
#   'jadi',
#   'kalau',
#   'sulit',
#   'dapat',
#   'tempat',
#   'yang',
#   'enak',
#   'terima',
#   'kasih',
#   'untuk'],
#  ['potong', 'baik'],
#  ['adil', 'uda', 'dapat', 'tempat', 'tiba', 'ada', 'yang', 'orang', 'lain'],
#  ['rasa', 'enak', 'layan', 'baik'],
#  ['lambat',
#   'lelet',
#   'parah',
#   'lama',
#   'banget',
#   'tidak',
#   'ramah',
#   'sangat',
#   'buruk',
#   'untuk',
#   'pegawai'],
#  ['kesini', 'sabtu', 'pagi', 'lumayan', 'opsi', 'kue', 'masih', 'lengkap'],
#  ['lumayan', 'lah', 'pas', 'super', 'bisa', 'sekali', 'jajan', 'sini'],
#  ['dua',
#   'kali',
#   'agak',
#   'malam',
#   'dikit',
#   'waktu',
#   'selalu',
#   'sudah',
#   'tutup',
#   'order',
#   'belah',
#   'masih',
#   'ramai',
#   'tidak',
#   'doyan',
#   'langgan'],
#  ['punya'],
#  ['pernah',
#   'bosan',
#   'sama',
#   'menu',
#   'dari',
#   'buah',
#   'dan',
#   'keju',
#   'karena',
#   'memang',
#   'enak',
#   'itu',
#   'kalo',
#   'lagi',
#   'swalayan',
#   'dekat',
#   'pasti',
#   'mampir',
#   'sini',
#   'atau',
#   'kalo',
#   'tidak',
#   'bisa',
#   'order',
#   'via',
#   'harga',
#   'juga',
#   'relatif',
#   'jangkau',
#   'untuk',
#   'tiap',
#   'varian',
#   'menu',
#   'kamu',
#   'suka',
#   'menu',
#   'apa',
#   'kalo',
#   'lagi'],
#  ['layan', 'ramah'],
#  ['tempat',
#   'bagus',
#   'cocok',
#   'buat',
#   'kumpul',
#   'bareng',
#   'teman',
#   'dan',
#   'keluarga',
#   'dengan',
#   'suasana',
#   'yang',
#   'nyaman',
#   'harga',
#   'masih',
#   'jangkau',
#   'dan',
#   'yang',
#   'lebih',
#   'penting',
#   'kasir',
#   'ramah',
#   'ramah'],
#  ['layan', 'ramah', 'banyak', 'promosi', 'mantap'],
#  ['suasana',
#   'nyaman',
#   'dan',
#   'bersih',
#   'layan',
#   'baik',
#   'dan',
#   'sabar',
#   'minum',
#   'paling',
#   'suka',
#   'cokelat',
#   'maaf',
#   'kalau',
#   'salah',
#   'tulis'],
#  ['meski', 'tempat', 'layan', 'baik', 'cepat', 'dan', 'ramah'],
#  ['nyaman', 'sangat', 'sampai', 'lupa', 'pulang'],
#  ['mau',
#   'jenak',
#   'santai',
#   'dan',
#   'cepat',
#   'bisa',
#   'banget',
#   'kopi',
#   'tempat',
#   'tidak',
#   'terlalu',
#   'luas',
#   'karena',
#   'memang',
#   'ini',
#   'khusus',
#   'kopi',
#   'cepat',
#   'ada',
#   'yang',
#   'spesial',
#   'loh',
#   'tempat',
#   'ini',
#   'karena',
#   'bisa',
#   'sambil',
#   'lihat',
#   'yang',
#   'nangkring',
#   'selamat',
#   'coba'],
#  [],
#  ['pesan', 'makan', 'menu', 'sampai', 'tunggu', 'menit'],
#  ['tempat',
#   'bagus',
#   'dan',
#   'estetik',
#   'aku',
#   'makan',
#   'nasi',
#   'campur',
#   'ayam',
#   'panggang',
#   'dan',
#   'cumi-cumi',
#   'hitam',
#   'bacem',
#   'ayam',
#   'empuk',
#   'manis',
#   'cumi-cumi',
#   'hitam',
#   'hanya',
#   'asin',
#   'yang',
#   'dominan',
#   'tekstur',
#   'cumi-cumi',
#   'juga',
#   'agak',
#   'liat',
#   'bacem',
#   'kecut',
#   'kes',
#   'kayak',
#   'sudah',
#   'basi',
#   'kata',
#   'teman',
#   'sih',
#   'banyak',
#   'asam',
#   'juga',
#   'agak',
#   'asam',
#   'banyak',
#   'tomat',
#   'porsi',
#   'nasi',
#   'lumayan',
#   'banyak',
#   'sih',
#   'masih',
#   'enak',
#   'yang',
#   'sih',
#   'ayo',
#   'jangan',
#   'mau',
#   'kalah',
#   'sama',
#   'tapi',
#   'tempat',
#   'sih'],
#  ['kurang',
#   'puas',
#   'pegawai',
#   'banyak',
#   'ketika',
#   'layan',
#   'beli',
#   'tunggu',
#   'waktu',
#   'menit',
#   'lebih',
#   'kurang',
#   'muas',
#   'layan',
#   'kasir'],
#  ['minum',
#   'enak',
#   'layan',
#   'ramah',
#   'suasana',
#   'nyaman',
#   'dan',
#   'banyak',
#   'promosi',
#   'juga',
#   'tentu',
#   'terima',
#   'kasih',
#   'minum'],
#  ['rasa',
#   'kopi',
#   'enak',
#   'layan',
#   'lumayan',
#   'cepat',
#   'terkadang',
#   'meja',
#   'kotor'],
#  ['suasana',
#   'tempat',
#   'yang',
#   'sangat',
#   'nyaman',
#   'dan',
#   'estetik',
#   'bikin',
#   'betah',
#   'tempat'],
#  ['kurang', 'pada', 'karena', 'ganggu', 'rumah', 'sekitar'],
#  ['lama',
#   'sekali',
#   'tunggu',
#   'pesan',
#   'tolong',
#   'baik',
#   'lagi',
#   'kerja',
#   'pesan'],
#  ['makan',
#   'dan',
#   'minum',
#   'yang',
#   'saya',
#   'pesan',
#   'sesuai',
#   'dengan',
#   'harga',
#   'enak',
#   'dan',
#   'banyak',
#   'varian',
#   'layan',
#   'juga',
#   'bagus',
#   'dan',
#   'untuk',
#   'makan',
#   'tempat',
#   'juga',
#   'nyaman',
#   'lebih',
#   'lagi',
#   'sana',
#   'ada',
#   'sofa',
#   'dan',
#   'mungkin',
#   'sofa',
#   'bisa',
#   'bersih',
#   'lagi'],
#  ['baru',
#   'jam',
#   'untuk',
#   'buka',
#   'puasa',
#   'nasi',
#   'habis',
#   'sedikit',
#   'kecewa'],
#  ['tempat', 'sangat', 'luas', 'parkir', 'motor', 'belakang'],
#  ['rasa',
#   'biasa',
#   'aja',
#   'kurang',
#   'cocok',
#   'harga',
#   'lumayan',
#   'mahal',
#   'ruang',
#   'tidak',
#   'dingin',
#   'seperti',
#   'dingin',
#   'tidak',
#   'nyala',
#   'atau',
#   'rusak',
#   'layan',
#   'kurang',
#   'ramah'],
#  ['tempat',
#   'keren',
#   'pegawai',
#   'juga',
#   'ramah',
#   'seperti',
#   'biasa',
#   'saya',
#   'pesan',
#   'kopi',
#   'kenang',
#   'mantan',
#   'kurang',
#   'es',
#   'dan',
#   'kurang',
#   'sugar'],
#  ['emang', 'top', 'utama', 'bakso', 'sangat', 'lembut'],
#  ['warung',
#   'legenda',
#   'cuma',
#   'sini',
#   'milik',
#   'hingga',
#   'pramusaji',
#   'ramah',
#   'pol'],
#  ['sekali'],
#  ['layan',
#   'sangat',
#   'buruk',
#   'sangat',
#   'tidak',
#   'bantu',
#   'sama',
#   'sekali',
#   'hanya',
#   'minta',
#   'sendok',
#   'saja',
#   'tidak',
#   'boleh',
#   'dengan',
#   'alas',
#   'pertama',
#   'tidak',
#   'ada',
#   'lalu',
#   'kalau',
#   'orang',
#   'pesan',
#   'roti',
#   'atau',
#   'kue',
#   'oleh',
#   'sebab',
#   'itu',
#   'pakai',
#   'apa',
#   'dan',
#   'alas',
#   'ikut',
#   'kana',
#   'isi',
#   'harga',
#   'sendok',
#   'emang',
#   'dari',
#   'emas',
#   'kali',
#   'masuk',
#   'akal',
#   'baru',
#   'kali',
#   'ini',
#   'alam',
#   'kopi',
#   'kenang',
#   'yang',
#   'sangat',
#   'buruk'],
#  ['lokasi',
#   'dalam',
#   'swalayan',
#   'simpang',
#   'jalan',
#   'cukup',
#   'mudah',
#   'temu',
#   'toko',
#   'depan',
#   'desain',
#   'interior',
#   'standar',
#   'seperti',
#   'pada',
#   'umum',
#   'tempat',
#   'tidak',
#   'terlalu',
#   'besar',
#   'namun',
#   'tetap',
#   'nyaman',
#   'untuk',
#   'aku',
#   'atau',
#   'untuk',
#   'tongkrong',
#   'dengan',
#   'teman',
#   'tempat',
#   'juga',
#   'bersih',
#   'juga',
#   'dingin',
#   'sangat',
#   'ramah',
#   'dan',
#   'cepat',
#   'sistem',
#   'layan',
#   'layan',
#   'menu',
#   'standar',
#   'seperti',
#   'pada',
#   'umum',
#   'harga',
#   'standar',
#   'seperti',
#   'pada',
#   'umum',
#   'bayar',
#   'dapat',
#   'guna',
#   'maupun',
#   'tunai',
#   'sedia',
#   'dan',
#   'cukup',
#   'oke',
#   'tidak',
#   'ada',
#   'kamar',
#   'mandi',
#   'gabung',
#   'dalam',
#   'cukup',
#   'banyak',
#   'tempat',
#   'isi',
#   'daya',
#   'untuk',
#   'ini',
#   'tidak',
#   'terlalu',
#   'ramai',
#   'kunjung',
#   'langgan',
#   'bisa',
#   'jadi',
#   'salah',
#   'satu',
#   'alternatif',
#   'jadi',
#   'tempat',
#   'tongkrong',
#   'atau',
#   'produktif',
#   'yang',
#   'nyaman'],
#  ['lot', 'saji', 'ampun'],
#  ['tidak',
#   'ramah',
#   'sudah',
#   'minta',
#   'untuk',
#   'bersih',
#   'meja',
#   'malah',
#   'tidak',
#   'bersih'],
#  ['lama',
#   'yang',
#   'legendaris',
#   'ayam',
#   'bakar',
#   'enak',
#   'sekali',
#   'anak',
#   'saya',
#   'lahap',
#   'makan',
#   'sini',
#   'semua',
#   'suka',
#   'sambal',
#   'enak',
#   'plus',
#   'tumis',
#   'kangkung',
#   'sedap',
#   'sekali',
#   'goreng',
#   'juga',
#   'enak',
#   'tempat',
#   'golong',
#   'besar',
#   'dan',
#   'bersih',
#   'prima',
#   'rasa',
#   'juga',
#   'banyak',
#   'cabang',
#   'memang',
#   'harga',
#   'agak',
#   'mahal',
#   'tapi',
#   'sangat',
#   'itu',
#   'dengan',
#   'rasa',
#   'untuk',
#   'parkir',
#   'ada',
#   'tapi',
#   'tidak',
#   'banyak',
#   'juga',
#   'coba',
#   'kue',
#   'lumpur',
#   'dan',
#   'pop',
#   'jagung',
#   'semua',
#   'enak',
#   'pernah',
#   'sesal',
#   'makan',
#   'ayam',
#   'bakar',
#   'prima',
#   'rasa'],
#  ['kasir', 'ramah', 'layan', 'juga', 'cepat', 'suka', 'sudah'],
#  ['nyaman', 'layan', 'ramah', 'cepat', 'juga'],
#  ['perlu',
#   'dari',
#   'kelola',
#   'tidak',
#   'tanya',
#   'nama',
#   'tidak',
#   'ada',
#   'minta',
#   'maaf',
#   'saat',
#   'saya',
#   'tanya',
#   'kenapa',
#   'akhir',
#   'ada',
#   'yang',
#   'lewat',
#   'dan',
#   'tidak',
#   'panggil',
#   'ulang',
#   'beli',
#   'tanggal',
#   'november',
#   'jam',
#   'saran',
#   'untuk',
#   'baik',
#   'terima',
#   'kasih'],
#  ['pesan',
#   'makan',
#   'ayam',
#   'bakar',
#   'cah',
#   'kangkung',
#   'es',
#   'jeruk',
#   'gurami',
#   'rasa',
#   'benar',
#   'enak',
#   'pecah',
#   'mulut',
#   'ketika',
#   'gigit',
#   'asa',
#   'banget',
#   'bumbu',
#   'sama',
#   'ikan',
#   'yang',
#   'segar',
#   'pecah',
#   'mulut',
#   'ayam',
#   'bakar',
#   'untuk',
#   'rasa',
#   'standar',
#   'kayak',
#   'ayam',
#   'bakar',
#   'pada',
#   'umum',
#   'cah',
#   'kangkung',
#   'rasa',
#   'enak',
#   'banget',
#   'guruh',
#   'asin',
#   'imbang',
#   'tekstur',
#   'ketika',
#   'gigit',
#   'masih',
#   'jadi',
#   'mantap',
#   'untuk',
#   'cah',
#   'kangkung',
#   'rekomendasi',
#   'nasi',
#   'putih',
#   'juga',
#   'pulen',
#   'enak',
#   'untuk',
#   'es',
#   'jeruk',
#   'standar',
#   'aja',
#   'untuk',
#   'makan',
#   'sama',
#   'pasang',
#   'dan',
#   'keluarga'],
#  ['kok',
#   'mbak',
#   'layan',
#   'tak',
#   'ramah',
#   'langgan',
#   'gelas',
#   'meja',
#   'saya',
#   'kasar',
#   'sekali'],
#  ['lokasi',
#   'sudut',
#   'akses',
#   'parkir',
#   'cukup',
#   'mudah',
#   'cukup',
#   'untuk',
#   'beberapa',
#   'kelompok',
#   'yang',
#   'mau',
#   'santa',
#   'bisa',
#   'buat',
#   'keluarga',
#   'tempat',
#   'atau',
#   'harga',
#   'standar',
#   'standar',
#   'area',
#   'tinggal',
#   'pilih',
#   'saja'],
#  ['sering',
#   'sini',
#   'cari',
#   'rujak',
#   'yang',
#   'bersih',
#   'kalo',
#   'pas',
#   'ada',
#   'tamu',
#   'ini',
#   'jadi',
#   'rujuk',
#   'sekarang',
#   'turut',
#   'rada',
#   'kurang',
#   'tempat',
#   'bau',
#   'ruang',
#   'bersih',
#   'tapi',
#   'kalo',
#   'rasa',
#   'rujak',
#   'masih',
#   'kalo',
#   'tidak',
#   'salah',
#   'kemarin',
#   'makan',
#   'sini',
#   'harga',
#   'rujak',
#   'sekitar',
#   'dan',
#   'minum',
#   'es',
#   'blewah'],
#  ['jujur',
#   'saya',
#   'bagai',
#   'nikmat',
#   'kopi',
#   'kenang',
#   'bahkan',
#   'jadi',
#   'salah',
#   'satu',
#   'kopi',
#   'favorit',
#   'saya',
#   'sangat',
#   'kecewa',
#   'pas',
#   'pesan',
#   'kopi',
#   'sini',
#   'mungkin',
#   'perlu',
#   'lagi',
#   'atau',
#   'bagaimana',
#   'cuman',
#   'tadi',
#   'saya',
#   'pesan',
#   'kurang',
#   'sugar',
#   'malah',
#   'rasa',
#   'kopi',
#   'tidak',
#   'ada',
#   'cuma',
#   'rasa',
#   'susu',
#   'doang',
#   'kopi',
#   'cuma',
#   'bukan',
#   'kali',
#   'pertama',
#   'saya',
#   'rasa',
#   'kenang',
#   'mantan',
#   'ini',
#   'tapi',
#   'tadi',
#   'saya',
#   'sampai',
#   'pikir',
#   'keras',
#   'apa',
#   'saya',
#   'yang',
#   'salah',
#   'pesan',
#   'tapi',
#   'nyata',
#   'emang',
#   'kurang',
#   'dari',
#   'segi',
#   'rasa',
#   'cukup',
#   'kecewa',
#   'moga',
#   'baik',
#   'lagi'],
#  ['masak',
#   'dapat',
#   'pesan',
#   'dari',
#   'tadi',
#   'sampai',
#   'tiba',
#   'restoran',
#   'belum',
#   'baut',
#   'sama',
#   'sekali',
#   'dan',
#   'malah',
#   'tanya',
#   'pesan',
#   'apa'],
#  ['restoran',
#   'yang',
#   'meski',
#   'harga',
#   'masuk',
#   'mahal',
#   'namun',
#   'selalu',
#   'ramai',
#   'karena',
#   'memang',
#   'makan',
#   'sangat',
#   'enak',
#   'cabang',
#   'yang',
#   'ini',
#   'ada',
#   'lantai',
#   'atas',
#   'juga',
#   'guna',
#   'kalau',
#   'lantai',
#   'yang',
#   'bawah',
#   'sudah',
#   'penuh',
#   'layan',
#   'sangat',
#   'ramah',
#   'dan',
#   'selalu',
#   'senyum'],
#  ['tidak', 'ramah', 'mbak', 'cemberut', 'aja', 'muka', 'kecut'],
#  ['mantap', 'ini'],
#  ['tempat', 'strategis'],
#  ['tempat',
#   'lebih',
#   'oke',
#   'dari',
#   'kopi',
#   'yang',
#   'lain',
#   'juga',
#   'semua',
#   'bahan',
#   'benar',
#   'segar',
#   'banget',
#   'makan',
#   'bumbu',
#   'pas',
#   'jadi',
#   'asa',
#   'segar',
#   'dan',
#   'enak',
#   'pas',
#   'makan',
#   'sayang',
#   'layan',
#   'mungkin',
#   'karena',
#   'yang',
#   'layan',
#   'masih',
#   'pakai',
#   'baju',
#   'item',
#   'atau',
#   'masih',
#   'baru',
#   'jadi',
#   'sudah',
#   'maklum',
#   'harus',
#   'kalo',
#   'kurang',
#   'sadar',
#   'sama',
#   'pesan',
#   'yang',
#   'pes',
#   'bisa',
#   'balik',
#   'lagi',
#   'konfirmasi',
#   'atau',
#   'harus',
#   'ulang',
#   'pesan',
#   'belum',
#   'balik'],
#  ['kesini',
#   'karena',
#   'dapat',
#   'promosi',
#   'suasana',
#   'nyaman',
#   'dingin',
#   'meski',
#   'agak',
#   'jauh',
#   'tapi',
#   'enak',
#   'karena',
#   'tidak',
#   'begitu',
#   'ramai',
#   'paling',
#   'favorit',
#   'gula',
#   'kopi'],
#  ['cocok',
#   'untuk',
#   'yang',
#   'cari',
#   'murah',
#   'tapi',
#   'enak',
#   'tempat',
#   'tidak',
#   'bad',
#   'sih',
#   'bintang',
#   'dari'],
#  ['layan',
#   'tidak',
#   'ramah',
#   'harga',
#   'mahal',
#   'tidak',
#   'ada',
#   'nota',
#   'pesan',
#   'tidak',
#   'sesuai',
#   'beli',
#   'kali',
#   'masih',
#   'pagi',
#   'sekitar',
#   'jam',
#   'jam',
#   'mosok',
#   'balung',
#   'sudah',
#   'habis',
#   'rek',
#   'tak',
#   'enak',
#   'rumah',
#   'tidak',
#   'aduh',
#   'cak',
#   'cabang',
#   'kecewa'],
#  ['layan',
#   'depot',
#   'sangat',
#   'sebal',
#   'ketus',
#   'nasi',
#   'campur',
#   'dengan',
#   'sayap',
#   'ayam',
#   'sangat',
#   'kecil',
#   'sekali',
#   'rasa',
#   'hambar',
#   'sangat',
#   'mahal',
#   'ada',
#   'tikus',
#   'dan',
#   'kecoak',
#   'liar',
#   'depot',
#   'itu'],
#  ['makan', 'mantap', 'sekali', 'dengan', 'harga', 'kompetitif'],
#  ['sejak',
#   'untuk',
#   'komposisi',
#   'ganti',
#   'rasa',
#   'beda',
#   'banget',
#   'kalo',
#   'tempat',
#   'iya',
#   'malah',
#   'kalo',
#   'bisa',
#   'tambah',
#   'luas',
#   'dan',
#   'kursi',
#   'sofa',
#   'tambah'],
#  ['makan', 'rasa', 'sangat', 'muas', 'lidah'],
#  ['sekarang', 'anjing', 'sudah', 'bebas', 'masuk', 'duduk', 'kursi', 'pula'],
#  ['aku', 'sih'],
#  ['dari',
#   'semua',
#   'cabang',
#   'yang',
#   'pernah',
#   'saya',
#   'kunjung',
#   'madya',
#   'lah',
#   'satu',
#   'cabang',
#   'yang',
#   'ada',
#   'lengkap',
#   'dengan',
#   'sandal',
#   'untuk',
#   'keren',
#   'sekali',
#   'butuh',
#   'konsumen',
#   'muslim',
#   'perlu',
#   'tambah',
#   'jalur',
#   'colok',
#   'listrik',
#   'harap',
#   'maklum'],
#  ['layan',
#   'cepat',
#   'ramah',
#   'makan',
#   'enak',
#   'parkir',
#   'preman',
#   'banget',
#   'parkir',
#   'preman',
#   'banget',
#   'langsung',
#   'arah',
#   'parkir',
#   'tempat',
#   'yang',
#   'sedia',
#   'lahan',
#   'oleh',
#   'ibu',
#   'kenapa',
#   'paksa',
#   'bayar',
#   'tanpa',
#   'karcis',
#   'parkir',
#   'apakah',
#   'memang',
#   'begitu',
#   'parkir',
#   'depot',
#   'ibu',
#   'sayang',
#   'sekali',
#   'kalau',
#   'seperti',
#   'ini',
#   'bikin',
#   'orang',
#   'kapok',
#   'gara-gara',
#   'parkir'],
#  ['cocok', 'lidah'],
#  ['semua',
#   'kerja',
#   'memang',
#   'lelah',
#   'tapi',
#   'bagaimana',
#   'pun',
#   'kasir',
#   'harus',
#   'tetap',
#   'ramah',
#   'dan',
#   'minimal',
#   'sapa',
#   'langgan'],
#  ['kopi', 'mantap', 'pas', 'dengan', 'selera'],
#  ['nyaman', 'enak'],
#  ['aku',
#   'suka',
#   'beli',
#   'sini',
#   'mbak',
#   'kasir',
#   'ramah',
#   'banget',
#   'bantu',
#   'sakal',
#   'kalo',
#   'benar',
#   'nama',
#   'baik',
#   'baik',
#   'terus',
#   'pegawai',
#   'minum',
#   'kaya',
#   'mbak'],
#  ['mantap', 'sekali', 'enak', 'rasa'],
#  ['oke',
#   'untuk',
#   'tongkrong',
#   'dan',
#   'tugas',
#   'tetapi',
#   'suasana',
#   'agak',
#   'sedikit',
#   'kurang'],
#  ['letak',
#   'dalam',
#   'swalayan',
#   'royal',
#   'plaza',
#   'lantai',
#   'paling',
#   'dasar',
#   'sering',
#   'sedia',
#   'bagai',
#   'promosi',
#   'tarik',
#   'seperti',
#   'ketika',
#   'saya',
#   'beli',
#   'ada',
#   'promosi',
#   'beli',
#   'kopi',
#   'harga',
#   'jadi',
#   'coba',
#   'cari',
#   'tahu',
#   'promosi',
#   'apa',
#   'yang',
#   'ada',
#   'dan',
#   'biasa',
#   'pasang',
#   'iklan',
#   'promosi',
#   'tarik',
#   'belah',
#   'stan',
#   'mereka',
#   'layan',
#   'ramah',
#   'tempat',
#   'bersih',
#   'dan',
#   'sedia',
#   'tempat',
#   'duduk',
#   'untuk',
#   'tunggu',
#   'harga',
#   'kopi',
#   'variasi',
#   'mulai',
#   'dari',
#   'hingga',
#   'sekitar',
#   'ada',
#   'menu',
#   'dan',
#   'juga',
#   'ada',
#   'aneka',
#   'lucu',
#   'dan',
#   'tarik',
#   'serta',
#   'roti',
#   'khas',
#   'mereka',
#   'yang',
#   'rasa',
#   'enak',
#   'dan',
#   'harga',
#   'jangkau'],
#  ['seru', 'juga', 'buat', 'main'],
#  ['baru',
#   'ini',
#   'makan',
#   'tempat',
#   'tetapi',
#   'duduk',
#   'atur',
#   'mau',
#   'kasir',
#   'bad',
#   'lah',
#   'jangan',
#   'sini',
#   'kalo',
#   'mau',
#   'makan',
#   'makan',
#   'tempat',
#   'jelek',
#   'sekali',
#   'makan',
#   'boleh',
#   'murah',
#   'cuma',
#   'kalau',
#   'layan',
#   'ampas',
#   'sama',
#   'aja',
#   'beli',
#   'udang',
#   'keju',
#   'gada',
#   'keju',
#   'dong',
#   'bolong',
#   'begitu',
#   'pas',
#   'gigit',
#   'kaya',
#   'saya',
#   'sudah',
#   'begitu',
#   'mi',
#   'sekali',
#   'sampai',
#   'seperti',
#   'mi',
#   'kuah',
#   'dah',
#   'kapok',
#   'lah',
#   'tidak',
#   'bakal',
#   'makan',
#   'gaco',
#   'lagi'],
#  ['dan',
#   'sahabat',
#   'layan',
#   'untuk',
#   'rasa',
#   'dari',
#   'minum',
#   'adalah',
#   'lebih',
#   'atau',
#   'kurang',
#   'tetapi'],
#  ['makan',
#   'enak',
#   'tempat',
#   'iya',
#   'cuma',
#   'kadang',
#   'lalat',
#   'sebal',
#   'juga'],
#  ['coklat', 'tidak', 'ada', 'obat'],
#  ['semua',
#   'semua',
#   'oke',
#   'cuman',
#   'satu',
#   'kurang',
#   'tempat',
#   'kurang',
#   'lebar',
#   'dan',
#   'kurang',
#   'privasi'],
#  ['beli',
#   'botok',
#   'mau',
#   'bawa',
#   'pulang',
#   'tidak',
#   'beri',
#   'tempat',
#   'biarpun',
#   'beli',
#   'tidak',
#   'boleh'],
#  ['ada',
#   'porsi',
#   'anak',
#   'yang',
#   'pas',
#   'minum',
#   'porsi',
#   'besar',
#   'dan',
#   'agak',
#   'manis'],
#  ['tutup',
#   'jam',
#   'berapa',
#   'aplikasi',
#   'tulis',
#   'jam',
#   'kata',
#   'tukang',
#   'parkir',
#   'jam'],
#  ['nyaman',
#   'pintu',
#   'kalau',
#   'pintu',
#   'bising',
#   'sama',
#   'dengan',
#   'acara',
#   'tahun'],
#  ['tempat', 'bagus'],
#  ['beli',
#   'hari',
#   'minggu',
#   'kasir',
#   'kek',
#   'galak',
#   'sekali',
#   'padahal',
#   'masih',
#   'sore',
#   'harus',
#   'belum',
#   'capek',
#   'capek',
#   'juga',
#   'boleh',
#   'lah',
#   'galak',
#   'langgan',
#   'ada',
#   'senyum',
#   'beli',
#   'varian',
#   'rasa',
#   'aja',
#   'kopi',
#   'bukan',
#   'untuk',
#   'nikmat',
#   'kopi',
#   'pesan',
#   'kurang',
#   'sugar',
#   'tapi',
#   'masih'],
#  ['yang',
#   'sangat',
#   'jelek',
#   'turut',
#   'saya',
#   'saya',
#   'dapat',
#   'pesan',
#   'terus',
#   'menu',
#   'kosong',
#   'tapi',
#   'aplikasi',
#   'mati',
#   'kita',
#   'bagai',
#   'kemudi',
#   'tidak',
#   'tahu',
#   'nahu',
#   'dengan',
#   'gampang',
#   'restoran',
#   'langsung',
#   'batal',
#   'dari',
#   'restoran',
#   'dia',
#   'punya',
#   'pikir',
#   'apa',
#   'harus',
#   'masak',
#   'langsung',
#   'batal',
#   'tau',
#   'begitu',
#   'sedang',
#   'apa',
#   'tunggu',
#   'kemudi',
#   'sampai',
#   'lantai',
#   'itu',
#   'jauh',
#   'tidak',
#   'sesuai',
#   'harap'],
#  ['mampir',
#   'sini',
#   'buat',
#   'lepas',
#   'dahaga',
#   'tempat',
#   'sederhana',
#   'pegawai',
#   'juga',
#   'baik',
#   'layan',
#   'cuma',
#   'mungkin',
#   'bisa',
#   'tambah',
#   'kursi',
#   'supaya',
#   'langgan',
#   'bisa',
#   'minum',
#   'sambil',
#   'duduk',
#   'atau',
#   'istirahat',
#   'sembari',
#   'tunggu',
#   'pesan',
#   'siap',
#   'ambil',
#   'waktu',
#   'itu',
#   'pesan',
#   'hijau',
#   'rasa',
#   'enak',
#   'sesuai',
#   'harga',
#   'moga',
#   'layan',
#   'yang',
#   'baik',
#   'bisa',
#   'tetap',
#   'tahan',
#   'sukses',
#   'selalu',
#   'lokasi',
#   'dalam',
#   'royal',
#   'plaza',
#   'jadi',
#   'parkir',
#   'letak',
#   'luar'],
#  ['semua'],
#  ['pesan',
#   'lewat',
#   'aplikasi',
#   'beli',
#   'dapat',
#   'tetapi',
#   'yang',
#   'datang',
#   'cuma',
#   'kembali',
#   'dana',
#   'juga',
#   'tidak',
#   'sesuai',
#   'turut',
#   'saya',
#   'sangat',
#   'kecewa'],
#  ['kopi', 'biar', 'tenang'],
#  ['enak',
#   'cuman',
#   'memang',
#   'karena',
#   'ibu',
#   'sudah',
#   'legenda',
#   'harga',
#   'sesuai',
#   'dengan',
#   'kantong'],
#  ['banyak', 'tapi', 'kurang', 'cekat'],
#  ['akhir',
#   'ada',
#   'kopi',
#   'kenang',
#   'stasiun',
#   'sekarang',
#   'kalo',
#   'mau',
#   'jalan',
#   'jarak',
#   'jauh',
#   'tidak',
#   'bingung',
#   'lagi',
#   'sama',
#   'makan',
#   'kopi',
#   'apa',
#   'lagi',
#   'bisa',
#   'paket',
#   'sama',
#   'roti',
#   'jalan',
#   'naik',
#   'kereta',
#   'api',
#   'jadi',
#   'lebih',
#   'senang'],
#  ['yang', 'antri', 'banyak', 'yang', 'jaga', 'cuma', 'orang', 'payah'],
#  ['pesan', 'minum', 'buat', 'jam', 'sendiri'],
#  ['lokasi',
#   'strategis',
#   'dan',
#   'layan',
#   'ramah',
#   'tapi',
#   'sayang',
#   'tidak',
#   'ada',
#   'area',
#   'untuk'],
#  ['tempat',
#   'bersih',
#   'ada',
#   'wastafel',
#   'dalam',
#   'lahan',
#   'parkir',
#   'juga',
#   'lumayan',
#   'menu',
#   'menu',
#   'banyak',
#   'variasi',
#   'untuk',
#   'rasa',
#   'itu',
#   'sesuai',
#   'selera',
#   'kalau',
#   'saya',
#   'personal',
#   'kurang',
#   'doyan',
#   'terlalu',
#   'asa',
#   'terasi'],
#  ['tempat', 'nyaman'],
#  ['harga', 'rasa', 'iya', 'tetap', 'jadi', 'restoran', 'suka'],
#  ['toilet', 'sering', 'jorok', 'tempat', 'nyaman'],
#  ['ramah',
#   'dan',
#   'nyaman',
#   'datang',
#   'sini',
#   'sambil',
#   'tunggu',
#   'rawat',
#   'kucing',
#   'pet',
#   'jam',
#   'masih',
#   'sepi',
#   'juga',
#   'masih',
#   'kosong',
#   'belum',
#   'pajang',
#   'tempat',
#   'nyaman'],
#  ['tempat', 'minum', 'kopi', 'yang', 'nyaman', 'dan', 'enak'],
#  ['sayang', 'area', 'cukup'],
#  ['pagi',
#   'pagi',
#   'bawa',
#   'teman',
#   'untuk',
#   'rapat',
#   'kafe',
#   'aplikasi',
#   'lokal',
#   'pandu',
#   'kopi',
#   'salah',
#   'satu',
#   'kafe',
#   'area',
#   'yang',
#   'buka',
#   'jam',
#   'tapi',
#   'apa',
#   'toko',
#   'masih',
#   'tutup',
#   'pegawai',
#   'dalam',
#   'belum',
#   'pakai',
#   'seragam',
#   'bilang',
#   'jam',
#   'yang',
#   'salah',
#   'ini',
#   'saya',
#   'atau',
#   'aplikasi',
#   'yang',
#   'tulis',
#   'info',
#   'jam',
#   'cuma',
#   'pesan',
#   'kopi',
#   'karena',
#   'yang',
#   'tugas',
#   'cuma',
#   'takut',
#   'lama',
#   'parkir',
#   'ada',
#   'depan',
#   'tetapi',
#   'batas'],
#  ['ada', 'nomor', 'yang', 'bisa', 'hubung'],
#  ['nyaman'],
#  ['tempat',
#   'nyaman',
#   'suasana',
#   'makin',
#   'sore',
#   'makin',
#   'tenang',
#   'cocok',
#   'buat',
#   'santai',
#   'bareng',
#   'keluarga'],
#  ['layan', 'sangat', 'ramah'],
#  ['udang'],
#  ['ken',
#   'bintang',
#   'kurang',
#   'dari',
#   'uda',
#   'sering',
#   'sekali',
#   'kopi',
#   'dari',
#   'masih',
#   'kecil',
#   'sampai',
#   'sekarang',
#   'uda',
#   'punya',
#   'anak',
#   'jadi',
#   'sampai',
#   'tau',
#   'menu',
#   'kurang',
#   'apa',
#   'hari',
#   'ini',
#   'pesan',
#   'saus',
#   'yang',
#   'biasa',
#   'kental',
#   'yang',
#   'pasti',
#   'ada',
#   'keju',
#   'seperti',
#   'cuma',
#   'siram',
#   'susu',
#   'uda',
#   'begitu',
#   'belum',
#   'pria',
#   'kata',
#   'maaf',
#   'kak',
#   'kita',
#   'keliru',
#   'pesan',
#   'bikin',
#   'kopi',
#   'tidak',
#   'apa',
#   'mungkin',
#   'karena',
#   'aku',
#   'tidak',
#   'mau',
#   'jadi',
#   'buat',
#   'susu',
#   'selain',
#   'itu',
#   'pesan',
#   'mentega',
#   'kopi',
#   'tidak',
#   'ada',
#   'rasa',
#   'kopi',
#   'seperti',
#   'kasi',
#   'aja',
#   'rasa',
#   'super',
#   'kesel',
#   'kapok',
#   'sekali',
#   'uda',
#   'tidak',
#   'akan',
#   'mau',
#   'lagi',
#   'balik',
#   'sini'],
#  ['seperti',
#   'biasa',
#   'selalu',
#   'pesan',
#   'kopi',
#   'kenang',
#   'mantan',
#   'kurang',
#   'sugar'],
#  ['makan', 'enak', 'harga', 'murah'],
#  ['pertama',
#   'kali',
#   'saya',
#   'tunggu',
#   'makan',
#   'dan',
#   'minum',
#   'lama',
#   'tunggu',
#   'padahal',
#   'tidak',
#   'ramai',
#   'amat',
#   'minta',
#   'tagih',
#   'juga',
#   'lama',
#   'harus',
#   'harus',
#   'lebih',
#   'aktif',
#   'sesal',
#   'banget',
#   'makan',
#   'sini'],
#  ['ada',
#   'tempat',
#   'buat',
#   'rokok',
#   'tempat',
#   'nyaman',
#   'sopan',
#   'dekat',
#   'dari',
#   'rumah'],
#  ['sambal', 'bikin', 'tidak', 'bisa'],
#  ['order',
#   'dua',
#   'kali',
#   'karena',
#   'suka',
#   'hot',
#   'kopi',
#   'sini',
#   'mbak',
#   'juga',
#   'ramah',
#   'malah',
#   'bicara',
#   'kalo',
#   'mau',
#   'ambil',
#   'luar',
#   'bisa',
#   'kok',
#   'jadi',
#   'tidak',
#   'usah',
#   'repot',
#   'jalan',
#   'masuk',
#   'dalam',
#   'dan',
#   'turut',
#   'saya',
#   'sama',
#   'sekali',
#   'tidak',
#   'lama',
#   'layan',
#   'kalo',
#   'lama',
#   'itu',
#   'mungkin',
#   'antri',
#   'lagi',
#   'banyak',
#   'abai',
#   'bintang',
#   'sini',
#   'karena',
#   'paling',
#   'seperti',
#   'itu',
#   'yang',
#   'ojek',
#   'yang',
#   'tidak',
#   'bisa',
#   'tunggu',
#   'dengan',
#   'sabar',
#   'kasi',
#   'tidak'],
#  ['kopi',
#   'enak',
#   'lebih',
#   'enak',
#   'banding',
#   'beli',
#   'yang',
#   'kemas',
#   'swalayan',
#   'atau',
#   'swalayan',
#   'layan',
#   'baik',
#   'dan',
#   'cepat',
#   'harga',
#   'lumayan'],
#  ['kopi', 'kenang', 'yang', 'lokasi', 'sekarang', 'ada', 'belah'],
#  ['layan',
#   'ramah',
#   'lagi',
#   'banyak',
#   'promosi',
#   'tempat',
#   'bersih',
#   'cocok',
#   'buat',
#   'obrol',
#   'santai',
#   'bareng',
#   'teman'],
#  ['cepat', 'layan'],
#  ['bagus',
#   'tempat',
#   'tetapi',
#   'itu',
#   'ramai',
#   'masyarakat',
#   'jual',
#   'are',
#   'sahabat',
#   'dan',
#   'kopi',
#   'adalah',
#   'enak'],
#  ['kesini', 'tiap', 'promosi', 'lumayan', 'tempat', 'oke', 'juga'],
#  ['kopi', 'mantan', 'andal'],
#  ['lokasi',
#   'baru',
#   'tempat',
#   'luas',
#   'nyaman',
#   'dingin',
#   'layan',
#   'kurang',
#   'senyum',
#   'waktu',
#   'itu',
#   'saya',
#   'pesan',
#   'saus',
#   'lupa',
#   'tidak',
#   'beri',
#   'saji',
#   'cepat',
#   'harga',
#   'tengah',
#   'atas',
#   'karena',
#   'plus',
#   'pajak',
#   'rasa',
#   'enak',
#   'dekorasi',
#   'bagus',
#   'suasana',
#   'ramai',
#   'tampil',
#   'masakan',
#   'bagus',
#   'variasi',
#   'menu',
#   'banyak',
#   'tidak',
#   'hanya',
#   'saja',
#   'ada',
#   'nasi',
#   'goreng',
#   'makan',
#   'anak',
#   'harga',
#   'rata',
#   'minum',
#   'teh'],
#  ['bagai',
#   'cinta',
#   'minum',
#   'saya',
#   'sangat',
#   'rekomendasi',
#   'untuk',
#   'jadi',
#   'pilih',
#   'pertama',
#   'anda',
#   'saat',
#   'haus'],
#  ['lumayan'],
#  ['untuk',
#   'layan',
#   'cepat',
#   'sekali',
#   'minum',
#   'selalu',
#   'kembali',
#   'suasana',
#   'hati',
#   'yang',
#   'lagi',
#   'buruk',
#   'tambah',
#   'lagi',
#   'lihat',
#   'pegawai',
#   'yang',
#   'selalu',
#   'ramah',
#   'baik',
#   'deh',
#   'pokok'],
#  ['tempat',
#   'tidak',
#   'terlalu',
#   'luas',
#   'cuman',
#   'lumayan',
#   'nyaman',
#   'dingin',
#   'dingin',
#   'sangat',
#   'dan',
#   'layan',
#   'mantap',
#   'min',
#   'toilet',
#   'aga',
#   'rumit',
#   'tidak',
#   'dalem'],
#  ['sen',
#   'apa',
#   'kasih',
#   'apa',
#   'juga',
#   'encer',
#   'ambil',
#   'luar',
#   'beli',
#   'minum',
#   'tidak',
#   'kasih',
#   'kantong',
#   'sedot',
#   'pun',
#   'tunggu',
#   'minta',
#   'baru',
#   'kasih',
#   'minum',
#   'bagaimana',
#   'tidak',
#   'pakai',
#   'sedot',
#   'layan',
#   'bad',
#   'sekali'],
#  ['layan',
#   'sangat',
#   'buruk',
#   'dan',
#   'sangat',
#   'lambat',
#   'dan',
#   'buruk',
#   'sekali',
#   'dan',
#   'sangat',
#   'buang',
#   'waktu',
#   'semua',
#   'jaga',
#   'cabang',
#   'sangat',
#   'tidak',
#   'sigap',
#   'dan',
#   'sering',
#   'canda',
#   'bagi',
#   'dapur'],
#  ['jajan',
#   'murah',
#   'cup',
#   'tadi',
#   'malam',
#   'tiba',
#   'ingin',
#   'dog',
#   'begitu',
#   'jadi',
#   'langsung',
#   'cus',
#   'cup',
#   'dekat',
#   'tanya',
#   'apa',
#   'ada',
#   'paket',
#   'paket',
#   'karena',
#   'memang',
#   'tidak',
#   'ada',
#   'menu',
#   'jadi',
#   'harus',
#   'tanya',
#   'tapi',
#   'belum',
#   'tentu',
#   'ada',
#   'pas',
#   'sekali',
#   'kemarin',
#   'ada',
#   'promosi',
#   'paket',
#   'dog',
#   'bisa',
#   'pilih',
#   'mau',
#   'beri',
#   'harga',
#   'paket',
#   'jadi',
#   'belum',
#   'kalau',
#   'tidak',
#   'promosi',
#   'harga',
#   'lumayan',
#   'hemat',
#   'ribu',
#   'tempat',
#   'seperti',
#   'biasa',
#   'lumayan',
#   'ramai',
#   'karena',
#   'emang',
#   'dog',
#   'enak',
#   'sekali',
#   'tebal',
#   'penuh',
#   'pakai',
#   'saus',
#   'lagi',
#   'uda',
#   'enak',
#   'dan',
#   'aku',
#   'juga',
#   'ambil',
#   'yang',
#   'itu',
#   'isi',
#   'ada',
#   'saus',
#   'juga',
#   'super',
#   'kental',
#   'meski',
#   'seperti',
#   'kecil',
#   'tetapi',
#   'super',
#   'enak',
#   'penuh',
#   'juga',
#   'buat',
#   'yang',
#   'ingin',
#   'aja',
#   'ini',
#   'iya',
#   'sekali',
#   'sekali',
#   'sekali',
#   'layan',
#   'oke',
#   'cuma',
#   'kurang',
#   'cepat',
#   'bersih',
#   'jadi',
#   'meja',
#   'beberapa',
#   'ada',
#   'yang',
#   'masih',
#   'kotor',
#   'tetapi',
#   'ini',
#   'iya',
#   'mungkin',
#   'karena',
#   'ramai',
#   'lebih',
#   'suka',
#   'dan',
#   'pasti',
#   'balik',
#   'lagi'],
#  ['layan', 'ramah', 'dan', 'cepat', 'minum', 'enak'],
#  ['banyak',
#   'lah',
#   'yang',
#   'sudah',
#   'tahu',
#   'merek',
#   'makan',
#   'tidak',
#   'ada',
#   'masalah',
#   'normal',
#   'aja',
#   'layan',
#   'sikap',
#   'dan',
#   'sampai',
#   'informasi',
#   'sudah',
#   'dukung',
#   'suasana',
#   'mungkin',
#   'bukan',
#   'arah',
#   'suasana',
#   'lebih',
#   'arah',
#   'bersih',
#   'dan',
#   'tempat',
#   'sampah',
#   'ruang',
#   'itu',
#   'debu',
#   'banget',
#   'itu',
#   'yang',
#   'cabang',
#   'mohon',
#   'minim',
#   'atau',
#   'bagaimana',
#   'cara',
#   'debu',
#   'itu',
#   'tidak',
#   'sampai',
#   'buat',
#   'pengap',
#   'dingin',
#   'cek',
#   'sudah',
#   'debu',
#   'sangat',
#   'atau',
#   'tidak',
#   'atau',
#   'beli',
#   'mesin',
#   'sedot',
#   'debu',
#   'ruang',
#   'kan',
#   'cabang',
#   'ramai',
#   'jadi',
#   'minim',
#   'lah',
#   'tempat',
#   'sampah',
#   'mungkin',
#   'buat',
#   'dengan',
#   'kontak',
#   'besar',
#   'yang',
#   'tidak',
#   'tahu',
#   'fungsi',
#   'apa',
#   'mulai',
#   'lah',
#   'aja',
#   'yang',
#   'kapasitas',
#   'lebih',
#   'besar',
#   'jadi',
#   'kesan',
#   'orang',
#   'mau',
#   'buang',
#   'sampah',
#   'aja',
#   'jadi',
#   'kek',
#   'malas',
#   'sudah',
#   'lihat',
#   'tempat',
#   'sampah',
#   'penuh',
#   'ramai',
#   'mu',
#   'masak',
#   'lihat',
#   'cuman',
#   'orang',
#   'yang',
#   'bisa',
#   'aja',
#   'ramai',
#   'pada',
#   'malam',
#   'hari',
#   'beberapa',
#   'kali',
#   'datang',
#   'cuman',
#   'kasihan',
#   'harus',
#   'bersih',
#   'harus',
#   'layan',
#   'langgan',
#   'ini',
#   'tidak',
#   'salah',
#   'pegawai',
#   'ini',
#   'salah',
#   'manajemen',
#   'yang',
#   'jalan',
#   'bisa',
#   'cek',
#   'ulang'],
#  ['sangat'],
#  ['tolong',
#   'perhati',
#   'lagi',
#   'buat',
#   'pegawai',
#   'masa',
#   'dapat',
#   'pesan',
#   'kemudi',
#   'sampai',
#   'belum',
#   'proses'],
#  ['enak', 'harga', 'lumayan', 'mahal', 'tempat', 'tongkrong', 'enak'],
#  ['tunggu', 'pesan', 'terlalu', 'lama'],
#  ['banyak',
#   'menu',
#   'yang',
#   'bisa',
#   'coba',
#   'nuansa',
#   'interior',
#   'nyaman',
#   'sedia',
#   'banyak',
#   'daftar',
#   'anggota',
#   'baru',
#   'gratis',
#   'minum'],
#  ['makan',
#   'enak',
#   'sekali',
#   'terus',
#   'suasana',
#   'juga',
#   'nyaman',
#   'lagu',
#   'juga',
#   'enak',
#   'dengar'],
#  ['enak',
#   'harga',
#   'sesuai',
#   'dengan',
#   'kualitas',
#   'masakan',
#   'layan',
#   'dari',
#   'pegawai',
#   'muas',
#   'tempat',
#   'luas',
#   'dan',
#   'suasana',
#   'tenang',
#   'buat',
#   'yang',
#   'ingin',
#   'makan',
#   'masakan',
#   'dengan',
#   'nyaman'],
#  ['seperti', 'mapan', 'pada', 'umum'],
#  ['lagi',
#   'rumit',
#   'cari',
#   'kopi',
#   'tengok',
#   'kanan',
#   'kiri',
#   'ketemu',
#   'sama',
#   'kopi',
#   'kenang',
#   'pas',
#   'depan',
#   'pintu',
#   'masuk',
#   'jadi',
#   'minum',
#   'kopi',
#   'deh',
#   'layan',
#   'cepat',
#   'dan',
#   'layan',
#   'sesuai',
#   'dengan',
#   'kopi',
#   'mau',
#   'pahit',
#   'sesuai',
#   'selera',
#   'mantap'],
#  ['enak', 'untuk'],
#  ['tempat', 'asyik', 'dan', 'minum', 'rasa', 'mantap'],
#  ['meski',
#   'banyak',
#   'unjung',
#   'tetapi',
#   'tempat',
#   'tidak',
#   'ada',
#   'kurang',
#   'enak'],
#  ['tempat', 'bagus', 'enak', 'buat', 'santa', 'telah', 'keliling', 'tetapi'],
#  ['ramah', 'layan'],
#  ['gurami', 'adalah', 'enak'],
#  ['tidak', 'enak', 'yang', 'masak', 'beda', 'kali'],
#  ['layan', 'baik', 'pegawai', 'ramah'],
#  ['layan',
#   'bagus',
#   'dari',
#   'kasir',
#   'salah',
#   'kasih',
#   'minum',
#   'tetapi',
#   'kita',
#   'juga',
#   'lupa',
#   'pesan',
#   'apa',
#   'jadi',
#   'asal',
#   'minum',
#   'aja',
#   'tetapi',
#   'kasir',
#   'ingat',
#   'kalau',
#   'kita',
#   'pesan',
#   'tapi',
#   'kasih',
#   'pesan',
#   'beda',
#   'tapi',
#   'sama',
#   'pria',
#   'pria',
#   'kasir',
#   'langsung',
#   'ganti',
#   'lagi',
#   'dengan',
#   'pesan',
#   'yang',
#   'benar',
#   'layan',
#   'baik',
#   'kerja',
#   'pria',
#   'tahan',
#   'pria',
#   'pria'],
#  ['bisa',
#   'duduk',
#   'jam',
#   'tanpa',
#   'tawar',
#   'menu',
#   'lumayan',
#   'jadi',
#   'tempat',
#   'lepas',
#   'penat',
#   'tanpa',
#   'keluar',
#   'uang'],
#  ['mantap',
#   'ramai',
#   'dari',
#   'langgan',
#   'cara',
#   'maupun',
#   'lebih',
#   'asyik',
#   'dan',
#   'lebih',
#   'kembang',
#   'saking',
#   'ramai',
#   'sampai',
#   'banyak',
#   'kemudi',
#   'ojek',
#   'dari',
#   'bagai',
#   'aplikasi',
#   'ojek',
#   'lihat',
#   'bagus',
#   'agam',
#   'beli',
#   'yang',
#   'tunjuk',
#   'indonesia',
#   'tunggal',
#   'bagai',
#   'macam',
#   'warna',
#   'tapi',
#   'tetap',
#   'satu',
#   'dan',
#   'rukun',
#   'bila',
#   'perlu',
#   'semua',
#   'para',
#   'ojek',
#   'gratis',
#   'untuk',
#   'parkir',
#   'kasihan',
#   'mereka',
#   'hanya',
#   'dar',
#   'ambil',
#   'pesan',
#   'saja',
#   'cuma',
#   'sebentar'],
#  ['makan',
#   'cukup',
#   'enak',
#   'saji',
#   'makan',
#   'agak',
#   'lama',
#   'mungkin',
#   'karena',
#   'volume',
#   'unjung',
#   'tempat',
#   'makan',
#   'dan',
#   'parkir',
#   'batas',
#   'namun',
#   'lokasi',
#   'strategis'],
#  ['parah', 'banget', 'lama', 'sangat', 'tolong', 'baik', 'kerja', 'pegawai'],
#  ['tempat', 'kopi', 'dengan', 'suasana', 'yang', 'kondusif', 'nyaman'],
#  ['mantap', 'bagus'],
#  ['lambat',
#   'pegawai',
#   'hanya',
#   'utama',
#   'makan',
#   'tempat',
#   'kemudi',
#   'ojek',
#   'dua',
#   'kurang',
#   'ramah',
#   'sama'],
#  ['banyak', 'varian'],
#  ['tempat',
#   'oke',
#   'nyaman',
#   'kamar',
#   'mandi',
#   'juga',
#   'oke',
#   'tetapi',
#   'sayang',
#   'air',
#   'selalu',
#   'dikit',
#   'oke'],
#  ['dan',
#   'cocok',
#   'dengan',
#   'minum',
#   'pas',
#   'terlalu',
#   'manis',
#   'sesuai',
#   'layan',
#   'bagus',
#   'tetap',
#   'tahan',
#   'enak',
#   'tidak',
#   'terlalu',
#   'manis'],
#  ['tempat', 'iya', 'dan', 'luas'],
#  ['ini',
#   'kafe',
#   'dengan',
#   'layan',
#   'baik',
#   'saat',
#   'ini',
#   'dengan',
#   'makan',
#   'juga',
#   'cukup',
#   'enak',
#   'area',
#   'parkir',
#   'yang',
#   'cukup',
#   'luas',
#   'bisa',
#   'juga',
#   'untuk',
#   'rapat',
#   'karena',
#   'ada',
#   'ruang',
#   'minus',
#   'cuma',
#   'satu',
#   'saja',
#   'tempat',
#   'salat',
#   'perlu',
#   'tingkat',
#   'jangan',
#   'taruh',
#   'belakang',
#   'seperti',
#   'tempat',
#   'hantu'],
#  ['pernah',
#   'tinggal',
#   'kalau',
#   'nasi',
#   'empal',
#   'udang',
#   'dan',
#   'sambal',
#   'hijau',
#   'enak',
#   'ada',
#   'aneka',
#   'oleh',
#   'juga',
#   'jadi',
#   'bisa',
#   'sekali',
#   'beli',
#   'oleh',
#   'sana'],
#  ['tempat',
#   'nyaman',
#   'fasilitas',
#   'oke',
#   'deh',
#   'bersih',
#   'iklan',
#   'tempat',
#   'main',
#   'anak',
#   'yang',
#   'cocok',
#   'buat',
#   'keluarga'],
#  ['suasana', 'tenang', 'enak', 'kalau', 'buat', 'kumpul', 'keluarga'],
#  ['kuah',
#   'enak',
#   'tapi',
#   'ayam',
#   'kalau',
#   'makan',
#   'sini',
#   'sedikit',
#   'banget',
#   'kayak',
#   'bukan',
#   'cak',
#   'asli'],
#  ['buruk',
#   'banget',
#   'tidak',
#   'kayak',
#   'sama',
#   'ramah',
#   'pantas',
#   'tempat',
#   'sepi'],
#  ['untuk',
#   'semua',
#   'kemudi',
#   'harap',
#   'lihat',
#   'kalau',
#   'antar',
#   'untuk',
#   'layan',
#   'langgan',
#   'saya',
#   'sudah',
#   'dua',
#   'kali',
#   'kena',
#   'pesan',
#   'ini',
#   'restoran',
#   'tanpa',
#   'alas',
#   'cup',
#   'alhasil',
#   'tumpah',
#   'tolong',
#   'periksa',
#   'untuk',
#   'mesin',
#   'pres',
#   'sering',
#   'bocor',
#   'tidak',
#   'bisa',
#   'cek',
#   'barang',
#   'bocor',
#   'atau',
#   'tidak',
#   'karena',
#   'kalau',
#   'kirim',
#   'sudah',
#   'kondisi',
#   'untuk',
#   'panggil',
#   'pusat',
#   'tolong',
#   'jawab',
#   'bila',
#   'ada',
#   'keluh',
#   'dari',
#   'layan',
#   'langgan',
#   'biar',
#   'tau',
#   'kondisi',
#   'lapang'],
#  ['saya',
#   'makan',
#   'empat',
#   'dengan',
#   'mama',
#   'saya',
#   'dan',
#   'anak',
#   'saya',
#   'saya',
#   'tunggu',
#   'makan',
#   'keluar',
#   'lama',
#   'sekali',
#   'akhir',
#   'saya',
#   'batal',
#   'menu',
#   'yang',
#   'belum',
#   'keluar',
#   'sangat',
#   'sayang',
#   'restoran',
#   'ini',
#   'utama',
#   'langgan',
#   'ojek',
#   'lebih',
#   'dahulu',
#   'untuk',
#   'pesan',
#   'ketika',
#   'saya',
#   'batal',
#   'dan',
#   'bayar',
#   'makan',
#   'baru',
#   'buru',
#   'siap',
#   'keluar',
#   'kenapa',
#   'belum',
#   'tidak',
#   'begitu',
#   'saja',
#   'utama',
#   'langgan',
#   'yang',
#   'datang'],
#  ['rasa', 'kuat', 'mantap', 'buat', 'cinta', 'kopi'],
#  ['ada', 'bensin', 'dekat', 'rang', 'arah'],
#  ['interior',
#   'bagus',
#   'dan',
#   'rasa',
#   'minum',
#   'sesuai',
#   'standar',
#   'dan',
#   'kue',
#   'oke',
#   'tadi',
#   'beli',
#   'tapi',
#   'dingin',
#   'mati',
#   'jadi',
#   'panas',
#   'banget',
#   'terus',
#   'rasa',
#   'jadi',
#   'enek',
#   'begitu',
#   'rasa',
#   'kue',
#   'bayar',
#   'sini',
#   'bisa',
#   'tunai',
#   'kartu',
#   'debit',
#   'saran',
#   'untuk',
#   'manajemen',
#   'untuk',
#   'perhati',
#   'atmosfer',
#   'karena',
#   'kalo',
#   'panas',
#   'sekali',
#   'bakal',
#   'ogah'],
#  ['datang',
#   'sini',
#   'pagi',
#   'sambil',
#   'tunggu',
#   'anak',
#   'main',
#   'layan',
#   'cepat',
#   'tempat',
#   'bersih',
#   'tenang',
#   'oke',
#   'untuk',
#   'tunggu'],
#  ['enak', 'menu', 'penyet', 'juga', 'pangsit', 'ayam'],
#  ['harga',
#   'kopi',
#   'lumayan',
#   'kalo',
#   'mau',
#   'segar',
#   'bisa',
#   'coba',
#   'pesan',
#   'yang',
#   'hijau',
#   'segar',
#   'ringan',
#   'rasa',
#   'kecil',
#   'manis'],
#  ['layan', 'sangat', 'ramah'],
#  ['pesan', 'gojek'],
#  ['goreng', 'ayam', 'sampai', 'emang', 'lama', 'itu'],
#  ['tempat',
#   'bersih',
#   'dan',
#   'nyaman',
#   'dan',
#   'juga',
#   'lumayan',
#   'sepi',
#   'tidak',
#   'terlalu',
#   'ramai',
#   'layan',
#   'baik',
#   'dan',
#   'ramah',
#   'terima',
#   'kasih',
#   'sukses',
#   'selalu',
#   'buat',
#   'milik',
#   'serta',
#   'para',
#   'tim',
#   'salam',
#   'sukses'],
#  ['penyet', 'juara', 'sambal', 'pedas', 'dan', 'gurih'],
#  ['tempat',
#   'makan',
#   'ini',
#   'sudah',
#   'legendaris',
#   'jadi',
#   'rasa',
#   'memang',
#   'khas',
#   'banyak',
#   'orang',
#   'datang',
#   'sini',
#   'namun',
#   'saya',
#   'kurang',
#   'sedikit',
#   'cocok',
#   'sama',
#   'sambal'],
#  ['bersih', 'layan', 'ramah'],
#  ['kalo',
#   'lagi',
#   'suntuk',
#   'sekali',
#   'minum',
#   'kopi',
#   'kedai',
#   'kopi',
#   'biar',
#   'pikir',
#   'saya',
#   'tenang'],
#  ['makan', 'enak', 'dan', 'layan', 'ramah'],
#  ['enak', 'sangat'],
#  ['lokasi',
#   'cukup',
#   'strategis',
#   'karena',
#   'persis',
#   'depan',
#   'jalan',
#   'besar',
#   'dan',
#   'mudah',
#   'cari',
#   'letak',
#   'dalam',
#   'area',
#   'belanja',
#   'buat',
#   'cabang',
#   'ini',
#   'strategis',
#   'bagi',
#   'para',
#   'cinta',
#   'kopi',
#   'tempat',
#   'dalam',
#   'ruang',
#   'yang',
#   'lengkap',
#   'dengan',
#   'cukup',
#   'sempit',
#   'dan',
#   'lebih',
#   'kecil',
#   'banding',
#   'dengan',
#   'area',
#   'luar',
#   'ruang',
#   'harga',
#   'jangkau',
#   'dan',
#   'cocok',
#   'guna',
#   'untuk',
#   'sama',
#   'sahabat'],
#  ['tempat', 'nyaman', 'dan', 'layan', 'bagus'],
#  ['layan', 'lama', 'banget', 'dahulu', 'yang', 'bungkus', 'kecewa'],
#  ['kalau',
#   'boleh',
#   'saran',
#   'tempat',
#   'duduk',
#   'yang',
#   'sudah',
#   'bolong',
#   'ganti',
#   'terus',
#   'suasana',
#   'juga',
#   'buat',
#   'nyaman',
#   'mungkin',
#   'konsep',
#   'itu',
#   'loh',
#   'paling',
#   'jaman',
#   'dahulu',
#   'dari',
#   'pada',
#   'toko',
#   'lain',
#   'kan',
#   'lak',
#   'jadi',
#   'tidak',
#   'betah',
#   'lama',
#   'lama',
#   'tongkrong',
#   'sana'],
#  ['bintang',
#   'toilet',
#   'bintang',
#   'kondisi',
#   'enas',
#   'kotor',
#   'dan',
#   'tidak',
#   'fungsi'],
#  ['sangat',
#   'muas',
#   'dan',
#   'ada',
#   'tempat',
#   'untuk',
#   'minum',
#   'luar',
#   'kios',
#   'untuk',
#   'harga',
#   'dan',
#   'menu',
#   'sama',
#   'saja',
#   'tapi',
#   'yang',
#   'ini',
#   'lebih',
#   'istimewa',
#   'tempat',
#   'yang',
#   'sepi',
#   'tambah',
#   'alam',
#   'untuk',
#   'aku',
#   'tidak',
#   'ganggu',
#   'ama',
#   'bising',
#   'orang',
#   'sekitar'],
#  ['kopi',
#   'uda',
#   'kenal',
#   'cinta',
#   'indonesia',
#   'harus',
#   'sini',
#   'kalo',
#   'minum',
#   'kopi',
#   'sini',
#   'aja'],
#  ['enak',
#   'saus',
#   'keju',
#   'baik',
#   'selalu',
#   'bantu',
#   'guna',
#   'poin',
#   'dan',
#   'bagai'],
#  ['layan',
#   'muas',
#   'minum',
#   'kualitas',
#   'suasana',
#   'nyaman',
#   'yang',
#   'saya',
#   'heran',
#   'mengapa',
#   'masih',
#   'ada',
#   'saja',
#   'preman',
#   'parkir',
#   'minta',
#   'karcis',
#   'parkir',
#   'timpal',
#   'dengan',
#   'belum',
#   'datang'],
#  ['tempat',
#   'kurang',
#   'nyaman',
#   'untuk',
#   'rapat',
#   'ada',
#   'sofa',
#   'kursi',
#   'keras',
#   'cocok',
#   'untuk',
#   'jadi',
#   'kopi',
#   'kurang',
#   'nyaman',
#   'untuk',
#   'rapat'],
#  ['yang', 'laki', 'tidak', 'ramah', 'bad', 'tingkah', 'laku'],
#  ['enak', 'nyaman'],
#  ['lokasi', 'enak', 'untuk', 'timur'],
#  ['rasa',
#   'sudah',
#   'jelas',
#   'enak',
#   'tidak',
#   'enak',
#   'jika',
#   'ada',
# ...
#   'inovasi',
#   'dari',
#   'kelola',
#   'agar',
#   'bisa',
#   'ramai',
#   'unjung'],
#  ['layan', 'lama'],
#  ['layan',
#   'buruk',
#   'dan',
#   'ada',
#   'yang',
#   'tidak',
#   'sopan',
#   'minum',
#   'juga',
#   'tidak',
#   'seperti',
#   'kopi',
#   'cabang',
#   'lain',
#   'tertawa'],
#  ['enak',
#   'dan',
#   'layan',
#   'ramah',
#   'mungkin',
#   'bisa',
#   'tambah',
#   'kipas',
#   'supaya',
#   'lebih',
#   'nyaman',
#   'lagi'],
#  ['tempat', 'minum', 'kopi', 'ter', 'oke'],
#  ['layan', 'ramah', 'sopan'],
#  ['layan', 'tidak', 'sopan'],
#  ['ada', 'tempat', 'untuk', 'makan', 'sini'],
#  ['pas',
#   'masuk',
#   'restoran',
#   'suasana',
#   'nyaman',
#   'sekali',
#   'sambut',
#   'dengan',
#   'layan',
#   'mbak',
#   'yang',
#   'ramah',
#   'makan',
#   'juga',
#   'enak',
#   'mantap',
#   'sekali'],
#  ['makan',
#   'enak',
#   'layan',
#   'baik',
#   'dan',
#   'ramah',
#   'bagus',
#   'deh',
#   'suka',
#   'banget',
#   'tiap',
#   'sini',
#   'nyaman',
#   'juga',
#   'tempat'],
#  ['tempat',
#   'minum',
#   'kopi',
#   'area',
#   'yang',
#   'buka',
#   'cocok',
#   'kalo',
#   'mau',
#   'tongkrong',
#   'minum',
#   'kopi',
#   'malam',
#   'sama',
#   'teman'],
#  ['salah',
#   'satu',
#   'favorit',
#   'layan',
#   'ramah',
#   'tempat',
#   'luas',
#   'sedia',
#   'area',
#   'rasa',
#   'konsisten',
#   'buka',
#   'jam',
#   'cocok',
#   'buat',
#   'kejar',
#   'tugas'],
#  ['seru', 'temu', 'sini', 'ini', 'telah', 'long'],
#  ['letak',
#   'empat',
#   'jalan',
#   'depan',
#   'dapat',
#   'gereja',
#   'lama',
#   'lokasi',
#   'sangat',
#   'strategis',
#   'dan',
#   'mudah',
#   'temu',
#   'akses',
#   'parkir',
#   'juga',
#   'mudah',
#   'tempat',
#   'luas',
#   'dan',
#   'milik',
#   'lantai',
#   'dalam',
#   'ruang',
#   'dan',
#   'luar',
#   'ruang',
#   'ada',
#   'banyak',
#   'meja',
#   'yang',
#   'sedia',
#   'sini',
#   'dingin',
#   'sekali',
#   'utama',
#   'saat',
#   'malam',
#   'hari',
#   'cepat',
#   'dan',
#   'ramah',
#   'menu',
#   'seperti',
#   'pada',
#   'umum',
#   'harga',
#   'masih',
#   'jangkau',
#   'terkadang',
#   'ada',
#   'promosi',
#   'lalu',
#   'atau',
#   'aplikasi',
#   'resmi',
#   'bayar',
#   'bisa',
#   'atau',
#   'tunai',
#   'sedia',
#   'dan',
#   'cepat',
#   'toilet',
#   'lantai',
#   'dan',
#   'bersih',
#   'ada',
#   'banyak',
#   'tempat',
#   'isi',
#   'daya',
#   'salah',
#   'satu',
#   'timur',
#   'yang',
#   'nyaman',
#   'cocok',
#   'untuk',
#   'aku',
#   'dan',
#   'temu',
#   'teman'],
#  ['boleh',
#   'lah',
#   'sekal',
#   'sini',
#   'makan',
#   'biasa',
#   'saja',
#   'kata',
#   'enak',
#   'cukup',
#   'lumayan',
#   'bilang',
#   'enak',
#   'cukup',
#   'layak',
#   'makan',
#   'biasa',
#   'order',
#   'ikan',
#   'semua',
#   'karena',
#   'rekomendasi',
#   'ikan'],
#  ['tempat', 'enak', 'biarpun', 'tidak', 'luas', 'suasana', 'nyaman'],
#  ['depot',
#   'ibu',
#   'antri',
#   'kemudi',
#   'gojek',
#   'kalau',
#   'dapat',
#   'order',
#   'ibu',
#   'itu',
#   'dahulu',
#   'sama',
#   'langgan',
#   'uang',
#   'parkir',
#   'tidak',
#   'ada'],
#  ['saya',
#   'sering',
#   'banget',
#   'makan',
#   'tempat',
#   'ini',
#   'tapi',
#   'lama',
#   'lama',
#   'sambal',
#   'kok',
#   'kurang',
#   'sip',
#   'apa',
#   'karena',
#   'yang',
#   'ganti'],
#  ['alam',
#   'kurang',
#   'asyik',
#   'tapi',
#   'untung',
#   'tanggap',
#   'dengan',
#   'baik',
#   'sama',
#   'manajer',
#   'moga',
#   'bisa',
#   'jadi',
#   'baik',
#   'depan'],
#  ['layan', 'lama'],
#  ['nyaman', 'dan'],
#  ['layan', 'ramah', 'dan', 'cepat', 'minum', 'enak', 'sama', 'harga'],
#  ['pesan', 'cepat', 'sampai'],
#  ['lamban',
#   'apalagi',
#   'kalo',
#   'kemudi',
#   'tunggu',
#   'sampai',
#   'ini',
#   'kelar',
#   'meski',
#   'datang',
#   'dahulu'],
#  ['makan', 'enak'],
#  ['tempat', 'bagus', 'bersih', 'parkir', 'juga', 'luas', 'ramah'],
#  ['ramah', 'nyaman', 'dan', 'aman'],
#  ['tempat', 'asri', 'dan', 'nyaman'],
#  ['kecewa',
#   'aja',
#   'semua',
#   'sih',
#   'jadi',
#   'jauh',
#   'jadi',
#   'baik',
#   'enggak',
#   'tau',
#   'kenapa',
#   'kali',
#   'ini',
#   'kosong',
#   'pesan',
#   'iga',
#   'penyet',
#   'yang',
#   'datang',
#   'aku',
#   'kira',
#   'bakal',
#   'enak',
#   'tapi',
#   'malah',
#   'dapat',
#   'iga',
#   'yang',
#   'super',
#   'alot',
#   'gosong',
#   'dan',
#   'enggak',
#   'bisa',
#   'makan',
#   'cuman',
#   'cuil',
#   'aja',
#   'sumpah',
#   'kali',
#   'ini',
#   'kecewa'],
#  ['enak',
#   'untuk',
#   'rehat',
#   'samping',
#   'jalan',
#   'raya',
#   'parkir',
#   'mobil',
#   'luas'],
#  ['enak',
#   'buat',
#   'per',
#   'cabang',
#   'yang',
#   'lain',
#   'minus',
#   'parkir',
#   'susah',
#   'karena',
#   'deret',
#   'dengan',
#   'rumah',
#   'toko',
#   'lain',
#   'dan',
#   'pinggir',
#   'jalan'],
#  ['enak', 'nyaman', 'sangat'],
#  ['ramah', 'baik', 'tempat', 'dan', 'suasana', 'nyaman', 'deh'],
#  ['tempat',
#   'strategis',
#   'buat',
#   'lokasi',
#   'aku',
#   'dan',
#   'harga',
#   'mahasiswa',
#   'bisa',
#   'banget',
#   'begitu',
#   'enak',
#   'bagus',
#   'deh'],
#  ['sih',
#   'buat',
#   'segala',
#   'sini',
#   'makan',
#   'benar',
#   'benar',
#   'bagus',
#   'indah',
#   'rasa',
#   'asyik',
#   'ramah',
#   'banget',
#   'dari',
#   'awal',
#   'masuk',
#   'suasana',
#   'tenang',
#   'adem',
#   'dan',
#   'mewah',
#   'nuansa',
#   'kafe',
#   'kafe',
#   'tinggi',
#   'kelas'],
#  ['tempat',
#   'nyaman',
#   'dan',
#   'enak',
#   'untuk',
#   'makan',
#   'sama',
#   'teman',
#   'dan',
#   'keluarga'],
#  ['tempat',
#   'kafe',
#   'tempat',
#   'nyaman',
#   'dan',
#   'tidak',
#   'terlalu',
#   'ramai',
#   'adalah',
#   'baik'],
#  ['layan', 'atas', 'tolong', 'bimbing', 'kurang', 'sopan'],
#  ['minum', 'favorit', 'sejak', 'sekolah'],
#  ['makan',
#   'oke',
#   'bersih',
#   'kurang',
#   'apalagi',
#   'pegawai',
#   'makan',
#   'sembarang',
#   'tempat'],
#  ['menit', 'pesan', 'belum', 'selesai', 'padahal', 'tamu', 'lengang'],
#  ['tunggu',
#   'anak',
#   'ekstra',
#   'basket',
#   'panah',
#   'selalu',
#   'dingin',
#   'kopi',
#   'kenang',
#   'layan',
#   'baik',
#   'racik',
#   'iya',
#   'juga',
#   'bersih'],
#  ['layan',
#   'ramah',
#   'sekali',
#   'kopi',
#   'juga',
#   'enak',
#   'segar',
#   'ramu',
#   'beda',
#   'dari',
#   'kopi',
#   'kenang',
#   'lain'],
#  ['baik', 'lagi', 'masalah', 'urut', 'antri'],
#  ['sangat',
#   'tidak',
#   'profesional',
#   'jam',
#   'masih',
#   'belum',
#   'buka',
#   'ini',
#   'loh',
#   'saya',
#   'tunggu',
#   'aja',
#   'dalam',
#   'mau',
#   'tahu',
#   'sampai',
#   'kapan',
#   'jual',
#   'saya',
#   'mau',
#   'pesan',
#   'apa',
#   'tapi',
#   'memang',
#   'graha',
#   'pena',
#   'sangat',
#   'jauh',
#   'dari',
#   'harap',
#   'buah',
#   'gerai',
#   'baik',
#   'interior',
#   'maupun',
#   'profesionalitas',
#   'jual',
#   'yang',
#   'tunggu',
#   'saya',
#   'dan',
#   'ada',
#   'orang',
#   'langgan',
#   'hari',
#   'ini',
#   'rabu',
#   'tanggal'],
#  ['untuk',
#   'kopi',
#   'enak',
#   'kopi',
#   'ragam',
#   'sugar',
#   'roti',
#   'kenang',
#   'favorit',
#   'keju'],
#  ['mantap', 'banget'],
#  ['kafe', 'yang', 'nyaman', 'buat'],
#  ['layan', 'untuk', 'bungkus', 'parah'],
#  ['krim', 'sudah', 'agak', 'asam'],
#  ['saya',
#   'beli',
#   'kopi',
#   'aren',
#   'sama',
#   'mereka',
#   'beri',
#   'campur',
#   'air',
#   'putih',
#   'padahal',
#   'saya',
#   'beli',
#   'tempat',
#   'lain',
#   'tidak',
#   'ada',
#   'campur',
#   'isi',
#   'hanya',
#   'kopi',
#   'segar',
#   'dan',
#   'gula',
#   'aren'],
#  ['legendaris'],
#  ['letak',
#   'dekat',
#   'masjid',
#   'motor',
#   'parkir',
#   'dekat',
#   'pintu',
#   'masuk',
#   'gang'],
#  ['sen',
#   'kopi',
#   'kenang',
#   'mantan',
#   'kasi',
#   'kopi',
#   'akibat',
#   'aplikasi',
#   'yang',
#   'tidak',
#   'fleksibel',
#   'jelas',
#   'aplikasi',
#   'sudah',
#   'tera',
#   'mantan',
#   'cabang',
#   'tidak',
#   'ada',
#   'langgan',
#   'yang',
#   'rugi'],
#  ['enak', 'segar', 'tidak', 'sesal', 'kalo', 'makan', 'sini'],
#  ['tempat', 'enak', 'banget'],
#  ['enak',
#   'sekali',
#   'buat',
#   'kerja',
#   'tugas',
#   'kuliah',
#   'tempat',
#   'nyaman',
#   'sekali',
#   'dan',
#   'layan',
#   'sih',
#   'ramah',
#   'ramah',
#   'sangat'],
#  ['nyaman',
#   'sangat',
#   'tempat',
#   'layan',
#   'juga',
#   'oke',
#   'sangat',
#   'pokok',
#   'sangat',
#   'saran'],
#  ['layan', 'reng'],
#  ['makan',
#   'yang',
#   'saji',
#   'hampir',
#   'semua',
#   'enak',
#   'dengan',
#   'porsi',
#   'yang',
#   'cukup',
#   'banyak',
#   'dan',
#   'tampil',
#   'tarik',
#   'gugah',
#   'selera',
#   'area',
#   'parkir',
#   'juga',
#   'nyaman',
#   'dan',
#   'aman'],
#  ['bagus', 'harga', 'bisa', 'terima', 'porsi', 'iya'],
#  ['layan',
#   'cepat',
#   'tapi',
#   'toko',
#   'sempit',
#   'tidak',
#   'kayak',
#   'yang',
#   'tunjung',
#   'plaza'],
#  ['tempat',
#   'sangat',
#   'nyaman',
#   'apalagi',
#   'menu',
#   'yang',
#   'rekomendasi',
#   'ayam',
#   'pop',
#   'makan',
#   'yang',
#   'baik',
#   'bagi',
#   'cocok',
#   'buat',
#   'kalian',
#   'yang',
#   'pacar',
#   'atau',
#   'tugas'],
#  ['yang',
#   'benar',
#   'aja',
#   'rugi',
#   'dong',
#   'masa',
#   'pesan',
#   'gaco',
#   'level',
#   'rasa',
#   'kek',
#   'level',
#   'terus',
#   'gaco',
#   'level',
#   'rasa',
#   'kek',
#   'level'],
#  ['pertama',
#   'kali',
#   'kopi',
#   'sub',
#   'suasana',
#   'nyaman',
#   'layan',
#   'sangat',
#   'bantu',
#   'juga',
#   'cocok',
#   'dengan',
#   'saji',
#   'kopi',
#   'harga',
#   'layan',
#   'dan',
#   'produk',
#   'irama',
#   'terima',
#   'kasih'],
#  ['tolong',
#   'dong',
#   'jual',
#   'yang',
#   'masih',
#   'pakai',
#   'baju',
#   'putih',
#   'yang',
#   'sopan',
#   'kalau',
#   'bicara',
#   'sama',
#   'langgan',
#   'bukan',
#   'teriak',
#   'kayak',
#   'tarzan',
#   'bicara',
#   'sama',
#   'langgan',
#   'teriak',
#   'pikir',
#   'saya',
#   'budek',
#   'sudah',
#   'saya',
#   'antri',
#   'panjang',
#   'bisa',
#   'bisa',
#   'dia',
#   'saya',
#   'tidak',
#   'antri',
#   'depan',
#   'banyak',
#   'langgan',
#   'lain',
#   'tidak',
#   'sopan',
#   'tolong',
#   'dong',
#   'usaha',
#   'besar',
#   'kerja',
#   'orang',
#   'dengan',
#   'tingkah',
#   'laku',
#   'yang',
#   'baik',
#   'buat',
#   'orang',
#   'tidak',
#   'nyaman'],
#  ['mantap',
#   'seperti',
#   'lain',
#   'tempat',
#   'nyaman',
#   'bersih',
#   'layan',
#   'baik',
#   'cuma',
#   'pegawai',
#   'cowok',
#   'agak',
#   'sombong',
#   'mungkin',
#   'bisa',
#   'baik'],
#  ['info',
#   'dari',
#   'layan',
#   'aplikasi',
#   'tidak',
#   'bisa',
#   'guna',
#   'karena',
#   'tidak',
#   'bisa',
#   'akhir',
#   'anggota',
#   'tidak',
#   'bisa',
#   'guna',
#   'juga',
#   'tidak',
#   'bisa',
#   'salah',
#   'masuk',
#   'jumlah',
#   'tagih',
#   'untuk',
#   'masalah',
#   'benar',
#   'yang',
#   'tidak',
#   'bisa',
#   'alat',
#   'atau',
#   'layan',
#   'jika',
#   'layan',
#   'mohon',
#   'untuk',
#   'tahu',
#   'pertama',
#   'dan',
#   'akhir',
#   'minum',
#   'kopi',
#   'sini'],
#  ['akhir',
#   'ketemu',
#   'kopi',
#   'kenang',
#   'kawan',
#   'cepu',
#   'belum',
#   'ada',
#   'karena',
#   'buka',
#   'cabang',
#   'juga',
#   'dong',
#   'cepu'],
#  ['kopi',
#   'lebih',
#   'kaya',
#   'kopi',
#   'karena',
#   'es',
#   'campur',
#   'terlalu',
#   'cair',
#   'krim',
#   'cair',
#   'kek',
#   'kopi',
#   'iya'],
#  ['rasa',
#   'kopi',
#   'kurang',
#   'asa',
#   'telah',
#   'rasa',
#   'lidah',
#   'rasa',
#   'manis',
#   'hari',
#   'tidak',
#   'hilang',
#   'layan',
#   'cepat',
#   'karena',
#   'lagi',
#   'sepi'],
#  ['ini',
#   'restoran',
#   'tidak',
#   'niat',
#   'untuk',
#   'tidak',
#   'usah',
#   'order',
#   'dari',
#   'tadi',
#   'langgan',
#   'sudah',
#   'bayar',
#   'dahulu',
#   'via',
#   'aplikasi',
#   'malah',
#   'dahulu',
#   'yang',
#   'makan',
#   'tempat',
#   'profesional',
#   'mana',
#   'kalo',
#   'orang',
#   'pintar',
#   'sapa',
#   'apa',
#   'makan',
#   'tempat',
#   'yang',
#   'beli',
#   'aplikasi',
#   'sudah',
#   'kerja',
#   'sama',
#   'kan',
#   'langsung',
#   'siap',
#   'tapi',
#   'pegawai',
#   'anda',
#   'lalai',
#   'tolong',
#   'baik',
#   'itu',
#   'pegawai',
#   'biar',
#   'lebih',
#   'profesional',
#   'lagi',
#   'pegawai'],
#  ['kamis',
#   'februari',
#   'saya',
#   'datang',
#   'pukul',
#   'sekitar',
#   'layan',
#   'sangat',
#   'buruk',
#   'kasir',
#   'perempuan',
#   'sangat',
#   'ketus',
#   'padahal',
#   'tidak',
#   'terlalu',
#   'ramai',
#   'saat',
#   'itu'],
#  ['tempat', 'yang', 'tidak', 'ada', 'tempat', 'nih', 'mantap', 'kawan'],
#  ['beli',
#   'terlalu',
#   'lama',
#   'pegawai',
#   'kalau',
#   'tidak',
#   'bisa',
#   'kerja',
#   'ganti',
#   'aja',
#   'biar',
#   'cepat'],
#  ['tempat',
#   'makan',
#   'untuk',
#   'keluarga',
#   'atau',
#   'kawan',
#   'yang',
#   'nyaman',
#   'dan',
#   'bersih',
#   'pilih',
#   'makan',
#   'dan',
#   'minum',
#   'agam',
#   'dan',
#   'rasa',
#   'enak',
#   'saya',
#   'pesan',
#   'makan',
#   'bakar',
#   'tahu',
#   'goreng',
#   'makan',
#   'tumis',
#   'daun',
#   'labu',
#   'dan',
#   'bakwan',
#   'goreng',
#   'serta',
#   'es',
#   'kelapa',
#   'muda',
#   'dan',
#   'jus',
#   'semua',
#   'enak',
#   'untuk',
#   'harga',
#   'masih',
#   'sahabat',
#   'dan',
#   'bayar',
#   'bisa',
#   'pakai',
#   'dan',
#   'debit',
#   'juga',
#   'mantap',
#   'lah'],
#  ['resiko', 'sepeda', 'hilang', 'tempat', 'masuk', 'kelinci'],
#  ['tempat',
#   'nyaman',
#   'sekali',
#   'tidak',
#   'terlalu',
#   'ramai',
#   'selain',
#   'itu',
#   'jual',
#   'ramah',
#   'pun',
#   'lancar',
#   'jadi',
#   'salah',
#   'satu',
#   'tempat',
#   'yang',
#   'cocok',
#   'untuk',
#   'produktif',
#   'maupun',
#   'luang',
#   'waktu',
#   'untuk',
#   'baca'],
#  ['buat', 'minum', 'kopi', 'kalo', 'lagi', 'mampir'],
#  ['lokasi', 'tempat', 'lantai'],
#  ['tolong',
#   'perhati',
#   'untuk',
#   'aplikasi',
#   'aplikasi',
#   'tolong',
#   'buka',
#   'mesin',
#   'jangan',
#   'samping',
#   'kita',
#   'sama',
#   'sama',
#   'kerja',
#   'kalau',
#   'ada',
#   'pesan',
#   'tolong',
#   'buka',
#   'paham',
#   'jangan',
#   'tunggu',
#   'kemudi',
#   'datang',
#   'dikit',
#   'restoran',
#   'lain',
#   'sudah',
#   'proses',
#   'paham'],
#  ['antri',
#   'lama',
#   'banget',
#   'apalagi',
#   'pas',
#   'bulan',
#   'terkadang',
#   'kasir',
#   'juga',
#   'cuek',
#   'dan',
#   'kes',
#   'galak',
#   'kemas',
#   'makan',
#   'oke',
#   'tapi',
#   'kualitas',
#   'rasa',
#   'kurang',
#   'pas',
#   'kadang',
#   'manis',
#   'banget',
#   'kadang',
#   'kurang',
#   'manis',
#   'atau',
#   'banyak',
#   'es'],
#  ['pesan',
#   'level',
#   'kok',
#   'seperti',
#   'level',
#   'mulut',
#   'sampek',
#   'bakar',
#   'tidak',
#   'kayak',
#   'gaco',
#   'cabang',
#   'lain'],
#  ['saus',
#   'tidak',
#   'itu',
#   'jadi',
#   'tidak',
#   'saya',
#   'biasa',
#   'enak',
#   'tapi',
#   'sini',
#   'terlalu',
#   'matang',
#   'hingga',
#   'kopi',
#   'terlalu',
#   'lembek',
#   'kemudian',
#   'sudah',
#   'kita',
#   'keluh',
#   'masak',
#   'lagi',
#   'tetap',
#   'saja',
#   'masih',
#   'lembek',
#   'koki',
#   'mana',
#   'nih',
#   'langgan',
#   'sejak',
#   'tetapi',
#   'baru',
#   'ini',
#   'tidak',
#   'puas',
#   'jadi',
#   'bintang',
#   'untuk',
#   'promosi',
#   'iya',
#   'minum',
#   'iya',
#   'layan',
#   'baik'],
#  ['kafe', 'yang', 'letak', 'sedang', 'ada', 'cendol', 'dan', 'sekarang'],
#  ['lokasi', 'dekat', 'kasir', 'pasar', 'yang', 'lebih', 'premium'],
#  ['buat', 'makan', 'sama', 'keluarga'],
#  ['layan', 'cepat', 'dan', 'tepat'],
#  ['tempat',
#   'sangat',
#   'enak',
#   'untuk',
#   'tongkrong',
#   'rasa',
#   'dan',
#   'harga',
#   'minum',
#   'sangat',
#   'itu',
#   'untuk',
#   'beli'],
#  ['tiap', 'senin', 'dapat', 'promosi', 'kopi', 'terima', 'kasih'],
#  ['layan',
#   'kurang',
#   'ramah',
#   'suka',
#   'buru',
#   'kepada',
#   'beli',
#   'dalam',
#   'pilih',
#   'pesan'],
#  ['mas',
#   'ganteng',
#   'aku',
#   'sampai',
#   'gagal',
#   'fokus',
#   'pas',
#   'order',
#   'bagaimana',
#   'pun',
#   'kopi',
#   'kopi',
#   'keren'],
#  ['kopi', 'kenang', 'mantan', 'sih', 'paling', 'juara'],
#  ['stok', 'ayam', 'kurang', 'banyak', 'jam', 'sudah', 'habis'],
#  ['banyak', 'promosi', 'layan', 'ramah'],
#  ['saya',
#   'order',
#   'ikan',
#   'sambal',
#   'sereh',
#   'tapi',
#   'yang',
#   'datang',
#   'ikan',
#   'yang',
#   'kecil',
#   'sekali',
#   'seperti',
#   'hanya',
#   'ekor',
#   'saja',
#   'yang',
#   'restoran',
#   'yang',
#   'bagus',
#   'bisa',
#   'tidak',
#   'seperti',
#   'kecewa',
#   'saya'],
#  ['rasa', 'enak', 'utama', 'lumpia', 'udang', 'favorit', 'banget'],
#  ['sudah',
#   'tambah',
#   'kopi',
#   'sugar',
#   'persen',
#   'rasa',
#   'masih',
#   'manis',
#   'tidak',
#   'kayak',
#   'biasa',
#   'pesan',
#   'swalayan',
#   'kecewa',
#   'banget'],
#  ['bagus', 'saya', 'suka'],
#  ['masuk', 'susah'],
#  ['tempat', 'bersih'],
#  ['favorit',
#   'kacang',
#   'layan',
#   'oke',
#   'pegawai',
#   'ramah',
#   'banget',
#   'selalu',
#   'beli',
#   'minum',
#   'royal',
#   'deh',
#   'pokok'],
#  ['baik', 'pilih', 'kopi', 'kenang', 'mantan'],
#  ['enak', 'layan', 'ramah'],
#  ['iya', 'biasa', 'tempat', 'gelap'],
#  ['ada',
#   'pahit',
#   'kopi',
#   'campur',
#   'manis',
#   'cocok',
#   'juga',
#   'minum',
#   'ini',
#   'biasa',
#   'minum',
#   'kopi',
#   'aja',
#   'rumah',
#   'jadi',
#   'kurang',
#   'erti',
#   'rasa',
#   'kopi',
#   'yang',
#   'mantap',
#   'itu',
#   'bagaimana',
#   'layan',
#   'cepat',
#   'tidak',
#   'sampai',
#   'menit',
#   'uda',
#   'siap',
#   'layan'],
#  ['minus',
#   'cuma',
#   'ada',
#   'tukang',
#   'parkir',
#   'yang',
#   'kurang',
#   'manfaat',
#   'cuma',
#   'mau',
#   'ambil',
#   'uang',
#   'saja',
#   'motor',
#   'tidak',
#   'tata'],
#  ['kopi'],
#  ['muas'],
#  ['selalu',
#   'ramai',
#   'saat',
#   'jam',
#   'makan',
#   'siang',
#   'untuk',
#   'makan',
#   'lumayan',
#   'sambal',
#   'bagus'],
#  ['asyik',
#   'buat',
#   'santai',
#   'harga',
#   'jangkau',
#   'makan',
#   'enak',
#   'minum',
#   'jus',
#   'kurang',
#   'kental',
#   'buah',
#   'tambah',
#   'supaya',
#   'mantap'],
#  ...]

# %%
words = set()
for tokens in X_stop_words_filtered:
    words = words.union(set(tokens))

unknown_words = nlp.extract_unknown_words(words)
len(unknown_words)
# Out:
# 1346

# %%
(pd.DataFrame({'X': X, 'X_stop_words_filtered': X_stop_words_filtered})
 .assign(
   len_words=lambda df: df.X_stop_words_filtered.map(len),
   unknown_words=lambda df: df.X_stop_words_filtered.map(lambda words: nlp.extract_unknown_words(set(words))),
   len_unknown_words=lambda df: df.unknown_words.map(len)
 )
#  .loc[lambda df: df.len_unknown_words.gt(0)]
)
# Out:
#                                                       X  \
# 0     The waiter is not friendly, the person wears n...
# 1     kakaknya enak bangetttt, pelayanannya cepet ta...
# 2            Pelayanan sangatt ramah, banyak promoanyaa
# 3                           Tempatnya nyaman dan bersih
# 4     Pelayanan cepat dan bagus, coba Durian Coffee ...
# ...                                                 ...
# 1397  Iki yakopo seh, titik lokasimu kok nng jl ahma...
# 1398  Tempatnya enak, deket pintu keluar. Kalo menu ...
# 1399                       Pelayannya agak nyebelin sih
# 1400  Makanan nya untuk saya kurang cocok, hanya pis...
# 1401  Br prtm x ksini..krn memang mi mapan favorit k...
#
#                                   X_stop_words_filtered  len_words  \
# 0     [the, layan, adalah, tidak, sahabat, the, pers...         11
# 1     [kakak, enak, sangat, layan, cepat, tanggap, d...         11
# 2               [layan, sangat, ramah, banyak, promosi]          5
# 3                         [tempat, nyaman, dan, bersih]          4
# 4     [layan, cepat, dan, bagus, coba, durian, coffe...         10
# ...                                                 ...        ...
# 1397  [iki, yakopo, seh, titik, lokasi, kok, nng, ja...         10
# 1398  [tempat, enak, dekat, pintu, keluar, kalo, men...         13
# 1399                          [layan, agak, sebal, sih]          4
# 1400  [makan, nya, untuk, saya, kurang, cocok, hanya...         19
# 1401  [br, pertama, x, ke, sini, karena, memang, mi,...         26
#
#                         unknown_words  len_unknown_words
# 0                        [wears, the]                  2
# 1                                  []                  0
# 2                                  []                  0
# 3                                  []                  0
# 4                            [coffee]                  1
# ...                               ...                ...
# 1397  [yakopo, iki, yani, nng, ahmad]                  5
# 1398                        [excelso]                  1
# 1399                               []                  0
# 1400                  [nya, security]                  2
# 1401   [2, nya, br, ke, x, di, tmpat]                  7
#
# [1402 rows x 5 columns]
